# %%
# q1
str1 = "Hello"
str2 = 'there'
bob = str1 + str2
print(bob)
# Out:
# Hellothere

# %%
# q2
x = '40'
y = int(x) + 2
print(y)
# Out:
# 42

# %%
x = 'From marquard@uct.ac.za'
print(x[8])
# Out:
# q

# %%
x = 'From marquard@uct.ac.za'
print(x[14:3])

# %%
print('h')
# Out:
# h

# %%
x='From marquard@uct.ac.za'
print(x[14:3])

# %%
print(len('banana')*7)
# Out:
# 42

# %%
greet = 'Hello Bob'
print(greet.upper())
# Out:
# HELLO BOB

# %%
for letter in 'banana' :
    print(letter)
# Out:
# b
# a
# n
# a
# n
# a

# %%
data = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
pos = data.find('.')
print(data[pos:pos+3])
# Out:
# .ma

# %%
text = "X-DSPAM-Confidence:    0.8475";
print(text)
# Out:
# X-DSPAM-Confidence:    0.8475

# %%
pos=text.find(':')
value=text[pos+1]
print(value)

# %%
text = "X-DSPAM-Confidence:    0.8475";
print(text)
pos=text.find(':')
value=text[pos+1]
print(value)
# Out:
# X-DSPAM-Confidence:    0.8475

# %%
x = list(range(5))
print(x)
# Out:
# [0, 1, 2, 3, 4]

# %%
a = [1, 2, 3]
b = [4, 5, 6]
c = a + b

# %%
print(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
stuff = dict()
print(stuff.get('candy',0))
# Out:
# 0

# %%
x = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
y = x.items()

# %%
print(y)
# Out:
# dict_items([('chuck', 1), ('fred', 42), ('jan', 100)])

# %%
From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008

# %% [markdown]
# # Regular Expression

# %%
import re
x = 'From: Using the : character'
y = re.findall('^F.+:', x)
print(y)
# Out:
# ['From: Using the :']

# %%
sentence = "From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008"
y = re.findall("\S+?@\S+", sentence)
print(y)

# %%
import re
x='My 2 Fav numbers are 2 and 20'
y=re.findall('[0-9]+',x)

# %%
print(y)
# Out:
# ['2', '2', '20']

# %%
import re
file_read=open('regex_sum_271790.txt')
num_list=list()
for i in file_read:
    l=re.findall('[0-9]+',i)
    if len(l)<1:    continue
    for i in range(len(l)):
        num_list.append(l[i])
tot=0
for i in num_list:
    tot=tot+int(i)
print('The sum of Numbers in sample data is',tot)
# Out:
# The sum of Numbers in sample data is 500236

# %%
# Out:
# 500236

# %%
import re
hand=open('regex_sum_271790.txt')
x=list()
for line in hand:    
    y = re.findall('[0-9]+',line)
    x=x+y
sum=0
for i in x:
    sum=sum+int(i)
print('The sum of Numbers in sample data is',sum)
# Out:
# The sum of Numbers in sample data is 500236

# %% [markdown]
# # Network Sockets

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/intro-short.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')

mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Tue, 25 Feb 2020 16:29:01 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "1d3-54f6609240717"
# Accept-Ranges: bytes
# Content-Length: 467
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# Why should you learn to write programs?
#
# Writing programs (or programming) is a very creative
# and rewarding activity.  You can write programs for
# many reasons, ranging from making your living to solving
# a difficult data analysis problem to having fun to helping
# someone else solve a problem.  This book assumes that
# everyone needs to know how to program, and that once
# you know how to program you will figure out what you want
# to do with your newfound skills.

# %%
print(ord('H'))
# Out:
# 72

# %% [markdown]
# # Retrieving Web Pages

# %%
import urllib.request,urllib.parse,urllib.error

# %%
fhand=urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

# %%
for i in fhand:
    print(i.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
f=urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
op=dict()
for i in f:
    word=i.decode().split()
    for j in word:
        op[j]=op.get(j,0)+1
print(op)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %% [markdown]
# # Parsing Web PAges

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
url=input('ENter-')
#html= have complete data of url 
html=urllib.request.urlopen(url).read()
# soup is an object
soup=BeautifulSoup(html,'html.parser')
tags=soup('a')
for i in tags:
    print(i.get('href',None))
# Out:
# ENter-http://www.dr-chuck.com/page1.htm
# http://www.dr-chuck.com/page2.htm

# %%
# Example 2

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl
ctx=ssl.create_default_context()
ctx.check_hostname=False
ctx.verify_mode=ssl.CERT_NONE

url=input('Enter the url ')
html=urllib.request.urlopen(url,context=ctx).read()
soup=BeautifulSoup(html,'html.parser')
tags=soup()
for i in tags:
    print(i.get('href',None))
# Out:
# Enter the url http://www.dr-chuck.com/page1.htm
# None
# None
# http://www.dr-chuck.com/page2.htm

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl
ctx=ssl.create_default_context()
ctx.check_hostname=False
ctx.verify_mode=ssl.CERT_NONE

url=input('Enter the url ')
html=urllib.request.urlopen(url,context=ctx).read()
soup=BeautifulSoup(html,'html.parser')
tags=soup('a')
# a angel tages see view page
for i in tags:
    print(i.get('href',None))
# Out:
# Enter the url http://www.dr-chuck.com/page1.htm
# http://www.dr-chuck.com/page2.htm

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl
ctx=ssl.create_default_context()
ctx.check_hostname=False
ctx.verify_mode=ssl.CERT_NONE

url=input('Enter the url ')
html=urllib.request.urlopen(url,context=ctx).read()
soup=BeautifulSoup(html,'html.parser')
tags=soup('a')
# a angel tages see view page
for i in tags:
    print(i.get('href',None))
# Out:
# Enter the url http://www.dr-chuck.com/page1.htm
# http://www.dr-chuck.com/page2.htm

# %% [markdown]
# # Web Pages Questions

# %%
x = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

# %%
print(type(x))
# Out:
# <class 'http.client.HTTPResponse'>

# %%
#Question2

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl
ctx=ssl.create_default_context()
ctx.check_hostname=False
ctx.verify_mode=ssl.CERT_NONE

url=input('Enter the url ')
#url='http://py4e-data.dr-chuck.net/comments_271792.html'
html=urllib.request.urlopen(url,context=ctx).read()
soup=BeautifulSoup(html,'html.parser')
t=soup('span')
sum=0
for i in t:
    sum=sum+int(i.contents[0])
print('Contents:', sum)
# Out:
# Enter the url http://py4e-data.dr-chuck.net/comments_271792.html
# Contents: 2667

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl
ctx=ssl.create_default_context()
ctx.check_hostname=False
ctx.verify_mode=ssl.CERT_NONE

url=input('Enter the url ')
#url='http://py4e-data.dr-chuck.net/comments_271792.html'
html=urllib.request.urlopen(url,context=ctx).read()
soup=BeautifulSoup(html,'html.parser')
t=soup('span')
sum=0
for i in t:
    sum=sum+int(i.contents[0])
print(sum)
# Out:
# Enter the url http://py4e-data.dr-chuck.net/comments_271792.html
# 2667

# %%
#Question3

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl
ctx=ssl.create_default_context()
ctx.check_hostname=False
ctx.verify_mode=ssl.CERT_NONE

#url=input('Enter the url ')
url='http://py4e-data.dr-chuck.net/known_by_Angus.html'
html=urllib.request.urlopen(url,context=ctx).read()
soup=BeautifulSoup(html,'html.parser')
t=soup('a')
sum=0
for i in t:
    print(i.get('href',None))
    #link = t[17].get('href', None)
    #print(link)
# Out:
# http://py4e-data.dr-chuck.net/known_by_Keanna.html
# http://py4e-data.dr-chuck.net/known_by_Mathu.html
# http://py4e-data.dr-chuck.net/known_by_Kasra.html
# http://py4e-data.dr-chuck.net/known_by_Etain.html
# http://py4e-data.dr-chuck.net/known_by_Jaime.html
# http://py4e-data.dr-chuck.net/known_by_Kjae.html
# http://py4e-data.dr-chuck.net/known_by_Kadyleigh.html
# http://py4e-data.dr-chuck.net/known_by_Xabier.html
# http://py4e-data.dr-chuck.net/known_by_Madisson.html
# http://py4e-data.dr-chuck.net/known_by_Asa.html
# http://py4e-data.dr-chuck.net/known_by_Bentley.html
# http://py4e-data.dr-chuck.net/known_by_Gaia.html
# http://py4e-data.dr-chuck.net/known_by_Betheny.html
# http://py4e-data.dr-chuck.net/known_by_Kaylynn.html
# http://py4e-data.dr-chuck.net/known_by_Mirren.html
# http://py4e-data.dr-chuck.net/known_by_Divine.html
# http://py4e-data.dr-chuck.net/known_by_Peyton.html
# http://py4e-data.dr-chuck.net/known_by_Logyn.html
# http://py4e-data.dr-chuck.net/known_by_Killian.html
# http://py4e-data.dr-chuck.net/known_by_Coleen.html
# http://py4e-data.dr-chuck.net/known_by_Wilhelmina.html
# http://py4e-data.dr-chuck.net/known_by_Bilal.html
# http://py4e-data.dr-chuck.net/known_by_Derin.html
# http://py4e-data.dr-chuck.net/known_by_Cruz.html
# http://py4e-data.dr-chuck.net/known_by_Sree.html
# http://py4e-data.dr-chuck.net/known_by_Abbeygail.html
# http://py4e-data.dr-chuck.net/known_by_Juwairiyah.html
# http://py4e-data.dr-chuck.net/known_by_Lotte.html
# http://py4e-data.dr-chuck.net/known_by_Ellae.html
# http://py4e-data.dr-chuck.net/known_by_Eirin.html
# http://py4e-data.dr-chuck.net/known_by_Padraig.html
# http://py4e-data.dr-chuck.net/known_by_Blaise.html
# http://py4e-data.dr-chuck.net/known_by_Kaylie.html
# http://py4e-data.dr-chuck.net/known_by_Eve.html
# http://py4e-data.dr-chuck.net/known_by_Magdalena.html
# http://py4e-data.dr-chuck.net/known_by_Adil.html
# http://py4e-data.dr-chuck.net/known_by_Ariana.html
# http://py4e-data.dr-chuck.net/known_by_Cassieleigh.html
# http://py4e-data.dr-chuck.net/known_by_Shaun.html
# http://py4e-data.dr-chuck.net/known_by_Carys.html
# http://py4e-data.dr-chuck.net/known_by_Ciarian.html
# http://py4e-data.dr-chuck.net/known_by_Jason.html
# http://py4e-data.dr-chuck.net/known_by_Tansy.html
# http://py4e-data.dr-chuck.net/known_by_Nivedita.html
# http://py4e-data.dr-chuck.net/known_by_Chymari.html
# http://py4e-data.dr-chuck.net/known_by_Saraah.html
# http://py4e-data.dr-chuck.net/known_by_Anisa.html
# http://py4e-data.dr-chuck.net/known_by_Kean.html
# http://py4e-data.dr-chuck.net/known_by_Leonah.html
# http://py4e-data.dr-chuck.net/known_by_Deia.html
# http://py4e-data.dr-chuck.net/known_by_Johann.html
# http://py4e-data.dr-chuck.net/known_by_Arwa.html
# http://py4e-data.dr-chuck.net/known_by_Ivan.html
# http://py4e-data.dr-chuck.net/known_by_Jaelyn.html
# http://py4e-data.dr-chuck.net/known_by_Jon.html
# http://py4e-data.dr-chuck.net/known_by_Iagan.html
# http://py4e-data.dr-chuck.net/known_by_Schekina.html
# http://py4e-data.dr-chuck.net/known_by_Mya.html
# http://py4e-data.dr-chuck.net/known_by_Bow.html
# http://py4e-data.dr-chuck.net/known_by_Aden.html
# http://py4e-data.dr-chuck.net/known_by_Cohan.html
# http://py4e-data.dr-chuck.net/known_by_Murron.html
# http://py4e-data.dr-chuck.net/known_by_Nyla.html
# http://py4e-data.dr-chuck.net/known_by_Kelsey.html
# http://py4e-data.dr-chuck.net/known_by_Reagan.html
# http://py4e-data.dr-chuck.net/known_by_Remigiusz.html
# http://py4e-data.dr-chuck.net/known_by_Tamzyn.html
# http://py4e-data.dr-chuck.net/known_by_Shyanne.html
# http://py4e-data.dr-chuck.net/known_by_Kelsie.html
# http://py4e-data.dr-chuck.net/known_by_Susannah.html
# http://py4e-data.dr-chuck.net/known_by_Braegan.html
# http://py4e-data.dr-chuck.net/known_by_Roxy.html
# http://py4e-data.dr-chuck.net/known_by_Arayan.html
# http://py4e-data.dr-chuck.net/known_by_Chibudom.html
# http://py4e-data.dr-chuck.net/known_by_Darci.html
# http://py4e-data.dr-chuck.net/known_by_Aneilya.html
# http://py4e-data.dr-chuck.net/known_by_Kelsay.html
# http://py4e-data.dr-chuck.net/known_by_Aila.html
# http://py4e-data.dr-chuck.net/known_by_Korbyn.html
# http://py4e-data.dr-chuck.net/known_by_Hope.html
# http://py4e-data.dr-chuck.net/known_by_Juanita.html
# http://py4e-data.dr-chuck.net/known_by_Eni.html
# http://py4e-data.dr-chuck.net/known_by_Diesel.html
# http://py4e-data.dr-chuck.net/known_by_Harvey.html
# http://py4e-data.dr-chuck.net/known_by_Ketsia.html
# http://py4e-data.dr-chuck.net/known_by_Armen.html
# http://py4e-data.dr-chuck.net/known_by_Mayra.html
# http://py4e-data.dr-chuck.net/known_by_Annick.html
# http://py4e-data.dr-chuck.net/known_by_Elliot.html
# http://py4e-data.dr-chuck.net/known_by_Bret.html
# http://py4e-data.dr-chuck.net/known_by_Natalie.html
# http://py4e-data.dr-chuck.net/known_by_Alyse.html
# http://py4e-data.dr-chuck.net/known_by_Sammy.html
# http://py4e-data.dr-chuck.net/known_by_Joss.html
# http://py4e-data.dr-chuck.net/known_by_Yakup.html
# http://py4e-data.dr-chuck.net/known_by_Kasi.html
# http://py4e-data.dr-chuck.net/known_by_Boe.html
# http://py4e-data.dr-chuck.net/known_by_Audrey.html
# http://py4e-data.dr-chuck.net/known_by_Sarina.html
# http://py4e-data.dr-chuck.net/known_by_Sanaa.html

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
position = int(input("Enter position:"))-1
count = int(input("Enter count:"))
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')
Sequence = []
tags = soup('a')
for i in range(count):
    link = tags[position].get('href', None)
    print(link)
    Sequence.append(tags[position].contents[0])
    html = urllib.request.urlopen(link, context=ctx).read()
    soup = BeautifulSoup(html, 'html.parser')
    tags = soup('a')
    link = tags[position].get('href', None)
print(Sequence[-1])
# Out:
# Enter - http://py4e-data.dr-chuck.net/known_by_Angus.html
# Enter position:18
# Enter count:7
# http://py4e-data.dr-chuck.net/known_by_Logyn.html
# http://py4e-data.dr-chuck.net/known_by_Obosa.html
# http://py4e-data.dr-chuck.net/known_by_Zhen.html
# http://py4e-data.dr-chuck.net/known_by_Soukina.html
# http://py4e-data.dr-chuck.net/known_by_Umar.html
# http://py4e-data.dr-chuck.net/known_by_Leigham.html
# http://py4e-data.dr-chuck.net/known_by_Daniyal.html
# Daniyal

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

#url = 'http://python-data.dr-chuck.net/known_by_Conar.html'
url = input('Enter URL:')
count = int(input('Enter count:'))
position = int(input('Enter position:'))-1
html = urllib.request.urlopen(url).read()

soup = BeautifulSoup(html,"html.parser")
href = soup('a')
#print href

for i in range(count):
    link = href[position].get('href', None)
    print( href[position].contents[0])
    html = urllib.request.urlopen(link).read()
    soup = BeautifulSoup(html,"html.parser")
    href = soup('a')
# Out:
# Enter URL:http://py4e-data.dr-chuck.net/known_by_Angus.html
# Enter count:7
# Enter position:18
# Logyn
# Obosa
# Zhen
# Soukina
# Umar
# Leigham
# Daniyal

# %% [markdown]
# # Data on web

# %%
import urllib.request as ur
import xml.etree.ElementTree as et

url = input('Enter location: ')

total_number = 0
sum = 0

print('Retrieving', url)
xml = ur.urlopen(url).read()
print('Retrieved', len(xml), 'characters')

tree = et.fromstring(xml)
counts = tree.findall('.//count')
for count in counts:
    #print(count.text)
    sum += int(count.text)
    total_number += 1

print('Count:', total_number)
print('Sum:', sum)
# Out:
# Enter location: http://py4e-data.dr-chuck.net/comments_271794.xml
# Retrieving http://py4e-data.dr-chuck.net/comments_271794.xml
# Retrieved 4210 characters
# Count: 50
# Sum: 2224

# %% [markdown]
# # Python with Databases

# %%
A relation is set of tuples that have the same attributes.A tuple represent objects.

# %%
import sqlite3

conn = sqlite3.connect('emaildb.sqlite')
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Counts')

cur.execute('''
CREATE TABLE Counts (email TEXT, count INTEGER)''')

fname = input('Enter file name: ')
if (len(fname) < 1): fname = 'mbox-short.txt'
fh = open(fname)
for line in fh:
    if not line.startswith('From: '): continue
    pieces = line.split()
    email = pieces[1]
    cur.execute('SELECT count FROM Counts WHERE email = ? ', (email,))
    row = cur.fetchone()
    if row is None:
        cur.execute('''INSERT INTO counts (email, count)
                VALUES (?, 1)''', (email,))
    else:
        cur.execute('UPDATE Counts SET count = count + 1 WHERE email = ?',
                    (email,))
    conn.commit()

# https://www.sqlite.org/lang_select.html
sqlstr = 'SELECT email, count FROM Counts ORDER BY count DESC LIMIT 10'

for row in cur.execute(sqlstr):
    print(str(row[0]), row[1])

cur.close()
# Out:
# Enter file name: mbox-short.txt
# zqian@umich.edu 195
# mmmay@indiana.edu 161
# cwen@iupui.edu 158
# chmaurer@iupui.edu 111
# aaronz@vt.edu 110
# ian@caret.cam.ac.uk 96
# jimeng@umich.edu 93
# rjlowe@iupui.edu 90
# dlhaines@umich.edu 84
# david.horwitz@uct.ac.za 67

# %%
# Top Organisation

# %%
import sqlite3

conn = sqlite3.connect('orgdb.sqlite')
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Counts')

cur.execute('''
CREATE TABLE Counts (org TEXT, count INTEGER)''')

fname = input('Enter file name: ')
if (len(fname) < 1): fname = 'mbox-short.txt'
fh = open(fname)
for line in fh:
    if not line.startswith('From: '): continue
    pieces = line.split()
    email = pieces[1]
    (emailname, organization) = email.split("@")
    cur.execute('SELECT count FROM Counts WHERE org = ? ', (organization,))
    row = cur.fetchone()
    if row is None:
        cur.execute('''INSERT INTO Counts (org, count)
                VALUES (?, 1)''', (organization,))
    else:
        cur.execute('UPDATE Counts SET count = count + 1 WHERE org = ?',
                    (organization,))
    conn.commit()

sqlstr = 'select * from Counts where count=(select max(count) from Counts)'

for row in cur.execute(sqlstr):
    print(str(row[0]), row[1])

cur.close()
# Out:
# Enter file name: mbox-short.txt
# iupui.edu 536

# %% [markdown]
# # Musical Track Database

# %%
import xml.etree.ElementTree as ET
import sqlite3

conn = sqlite3.connect('trackdb.sqlite')
cur = conn.cursor()

# Make some fresh tables using executescript()
cur.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;
DROP TABLE IF EXISTS Genre;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Genre (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    len INTEGER, rating INTEGER, 
    count INTEGER,
    genre_id INTEGER
);
''')


fname = input('Enter file name: ')
if ( len(fname) < 1 ) : fname = 'Library.xml'

# <key>Track ID</key><integer>369</integer>
# <key>Name</key><string>Another One Bites The Dust</string>
# <key>Artist</key><string>Queen</string>
def lookup(d, key):
    found = False
    for child in d:
        if found : return child.text
        if child.tag == 'key' and child.text == key :
            found = True
    return None

stuff = ET.parse(fname)
all = stuff.findall('dict/dict/dict')
print('Dict count:', len(all))
for entry in all:
    if ( lookup(entry, 'Track ID') is None ) : continue

    name = lookup(entry, 'Name')
    artist = lookup(entry, 'Artist')
    album = lookup(entry, 'Album')
    count = lookup(entry, 'Play Count')
    rating = lookup(entry, 'Rating')
    length = lookup(entry, 'Total Time')
    genre=  lookup(entry, 'Genre')
    

    if name is None or artist is None or album is None : 
        continue

    print(name, artist, album, count, rating, length)

    cur.execute('''INSERT OR IGNORE INTO Artist (name) 
        VALUES ( ? )''', ( artist, ) )
    cur.execute('SELECT id FROM Artist WHERE name = ? ', (artist, ))
    artist_id = cur.fetchone()[0]
    
    cur.execute('''INSERT OR IGNORE INTO Genre (name) 
        VALUES ( ? )''', ( genre, ) ) 
    cur.execute('SELECT id FROM Genre WHERE name = ? ', (genre, ))
    genre_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Album (title, artist_id) 
        VALUES ( ?, ? )''', ( album, artist_id ) )
    cur.execute('SELECT id FROM Album WHERE title = ? ', (album, ))
    album_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Track
        (title, album_id, len, rating, count,genre_id) 
        VALUES ( ?, ?, ?, ?, ? ,?)''', 
        ( name, album_id, length, rating, count ,genre_id) )

    conn.commit()
# Out:
# Enter file name: Library.xml
# Dict count: 404
# Another One Bites The Dust Queen Greatest Hits 55 100 217103
# Asche Zu Asche Rammstein Herzeleid 79 100 231810
# Beauty School Dropout Various Grease 48 100 239960
# Black Dog Led Zeppelin IV 109 100 296620
# Bring The Boys Back Home Pink Floyd The Wall [Disc 2] 33 100 87118
# Circles Bryan Lee Blues Is 54 60 355369
# Comfortably Numb Pink Floyd The Wall [Disc 2] 36 100 384130
# Crazy Little Thing Called Love Queen Greatest Hits 38 100 163631
# Electric Funeral Black Sabbath Paranoid 44 100 293015
# Fat Bottomed Girls Queen Greatest Hits 38 100 257515
# For Those About To Rock (We Salute You) AC/DC Who Made Who 84 100 353750
# Four Sticks Led Zeppelin IV 84 100 284421
# Furious Angels Rob Dougan The Matrix Reloaded 54 100 330004
# Gelle Bryan Lee Blues Is 45 60 199836
# Going To California Led Zeppelin IV 100 100 215666
# Grease Various Grease 42 100 205792
# Hand of Doom Black Sabbath Paranoid 36 100 429609
# Hells Bells AC/DC Who Made Who 82 100 312946
# Hey You Pink Floyd The Wall [Disc 2] 23 100 282305
# I Worry Bryan Lee Blues Is 33 100 341315
# Iron Man Black Sabbath Paranoid 39 100 358530
# Is There Anybody Out There? Pink Floyd The Wall [Disc 2] 26 100 160679
# It was a Very Good Year Frank Sinatra Greatest Hits 39 100 268852
# Its Your Move Bryan Lee Blues Is 40 100 245002
# Jack the Stripper/Fairies Wear Boots Black Sabbath Paranoid 35 100 373995
# Killer Queen Queen Greatest Hits 34 100 181368
# Laichzeit Rammstein Herzeleid 41 100 262844
# Let me Down Easy Bryan Lee Blues Is 43 100 331441
# Misty Mountain Hop Led Zeppelin IV 88 100 278831
# No Low Down Bryan Lee Blues Is 39 100 245760
# Now You Are Gone America Greatest Hits 52 100 187559
# Outside The Wall Pink Floyd The Wall [Disc 2] 16 100 104437
# Paranoid Black Sabbath Paranoid 36 100 172930
# Planet Caravan Black Sabbath Paranoid 38 100 274938
# Pretty Jeanie Bryan Lee Blues Is 34 100 225175
# Rammstein Rammstein Herzeleid 45 100 265090
# Rat Salad Black Sabbath Paranoid 46 100 150230
# Rock & Roll Led Zeppelin IV 109 100 220891
# Rode Across the Desert America Greatest Hits 60 100 249887
# Sandy Various Grease 36 100 155742
# Shake Your Foundations AC/DC Who Made Who 85 100 233769
# Sister Golden Hair America Greatest Hits 60 100 202057
# Somebody To Love Queen Greatest Hits 17 100 297586
# Stairway To Heaven Led Zeppelin IV 93 100 481567
# Strangers in the Night Frank Sinatra Greatest Hits 42 100 158484
# Summer Nights Various Grease 35 100 216973
# Summer Wind Frank Sinatra Greatest Hits 46 100 177554
# Thats Life Frank Sinatra Greatest Hits 43 100 189988
# The Battle Of Evermore Led Zeppelin IV 110 100 351529
# The Blues "Is" Bryan Lee Blues Is 45 100 252238
# There it Is Bryan Lee Blues Is 35 100 395441
# Think Bryan Lee Blues Is 41 100 320339
# This Town Frank Sinatra Greatest Hits 44 100 185051
# Tin Man America Greatest Hits 50 100 210076
# Track 01 Billy Price Danger Zone 47 100 261825
# Track 02 Billy Price Danger Zone 42 100 165459
# Track 03 Billy Price Danger Zone 41 100 206471
# Messin with the Kid The Canettes Blues Band Self Titled 23 100 226377
# Track 04 Billy Price Danger Zone 37 100 257175
# Stormy Monday The Canettes Blues Band Self Titled 29 100 464143
# Track 05 Billy Price Danger Zone 42 100 230295
# Waiting on Ice Bryan Lee Blues Is 37 100 289384
# War Pigs/Luke's Wall Black Sabbath Paranoid 38 100 478197
# We Are The Champions Queen Greatest Hits 24 100 181864
# We Will Rock You Queen Greatest Hits 33 100 123559
# When Somebody Loves You Frank Sinatra Greatest Hits 43 100 117263
# When The Levee Breaks Led Zeppelin IV 83 100 427624
# You are the One that I Want Various Grease 31 100 169900
# You Done Me Wrong Bryan Lee Blues Is 35 100 200097
# You Shook Me All Night Long AC/DC Who Made Who 92 100 210938
# You're My Best Friend Queen Greatest Hits 31 100 172643
# Zion Fluke The Matrix Reloaded 47 100 273528
# Who Made Who AC/DC Who Made Who 110 100 207203
# D.T. AC/DC Who Made Who 90 None 173714
# Sink the Pink AC/DC Who Made Who 83 None 253466
# Ride On AC/DC Who Made Who 75 None 351268
# Chase the Ace AC/DC Who Made Who 93 None 181420
# Wollt Ihr Das Bett In Flammen Sehen Rammstein Herzeleid 50 None 317387
# Der Meister Rammstein Herzeleid 46 None 250801
# Weisses Fleisch Rammstein Herzeleid 52 None 215902
# Seemann Rammstein Herzeleid 34 None 288235
# Du Riechst So Gut Rammstein Herzeleid 50 None 289332
# Das Alte Leid Rammstein Herzeleid 46 None 344581
# Heirate Mich Rammstein Herzeleid 39 None 284734
# Herzeleid Rammstein Herzeleid 42 None 223425
# Baba O'Riley The Who Who's Next 45 None 298448
# Bargain The Who Who's Next 37 None 331676
# Love Ain't for Keeping The Who Who's Next 24 None 130560
# My Wife The Who Who's Next 17 None 213786
# The Song Is Over The Who Who's Next 14 None 375797
# Getting In Tune The Who Who's Next 27 None 288809
# Going Mobile The Who Who's Next 28 100 221910
# Behind Blue Eyes The Who Who's Next 43 None 221570
# Won't Get Fooled Again The Who Who's Next 21 None 511111
# Folsom Prison Blues Johnny Cash The Legend Of Johnny Cash 47 100 170004
# I Walk The Line Johnny Cash The Legend Of Johnny Cash 33 100 165720
# Get Rhythm Johnny Cash The Legend Of Johnny Cash 35 100 134530
# Big River Johnny Cash The Legend Of Johnny Cash 51 None 152711
# Guess Things Happen That Way Johnny Cash The Legend Of Johnny Cash 35 None 111386
# Ring Of Fire Johnny Cash The Legend Of Johnny Cash 30 100 157100
# Jackson Johnny Cash The Legend Of Johnny Cash 35 100 166530
# A Boy Named Sue (live) Johnny Cash The Legend Of Johnny Cash 37 None 226063
# You Raise Me Up Selah Hiding Place 9 None 302262
# Hold On, I'm Coming The Canettes Blues Band On Tap & In the Can 34 100 282566
# Got my Mojo Working The Canettes Blues Band On Tap & In the Can 52 100 310517
# Sweet Home Chicago The Canettes Blues Band On Tap & In the Can 27 100 375849
# Heavy Love The Canettes Blues Band On Tap & In the Can 28 100 253544
# Cold Cold Feeling The Canettes Blues Band On Tap & In the Can 43 100 261929
# Lonely Avenue The Canettes Blues Band On Tap & In the Can 24 100 292022
# Good Morning Little Schoolgirl The Canettes Blues Band On Tap & In the Can 20 100 278648
# Dust My Broom The Canettes Blues Band On Tap & In the Can 24 100 299311
# Gimme' Some Lovin The Canettes Blues Band On Tap & In the Can 35 100 227239
# Everybody Needs Somebody to Love The Canettes Blues Band On Tap & In the Can 24 100 195186
# Black Magic Woman The Canettes Blues Band On Tap & In the Can 31 100 442644
# Steppin' Rooster The Canettes Blues Band On Tap & In the Can 21 100 704862
# Our Love is Drifting The Canettes Blues Band On Tap & In the Can 15 100 292649
# Doin' 100 The Canettes Blues Band On Tap & In the Can 20 100 343980
# Mother Joy Matt Ender Natural Wonders Music Sampler 1999 463 None 287294
# Soldier's Lament Steve McDonald Natural Wonders Music Sampler 1999 371 None 347193
# Dulaman Altan Natural Wonders Music Sampler 1999 403 None 223007
# The Arrow Chris Spheeris Natural Wonders Music Sampler 1999 416 None 319869
# Spanish Eyes La Esperanza Natural Wonders Music Sampler 1999 375 None 259030
# Banana Bay Luis Villegas Natural Wonders Music Sampler 1999 403 None 198060
# Aguas De Marco Rosa Passos Natural Wonders Music Sampler 1999 407 None 179408
# Tamborea Energipsy Natural Wonders Music Sampler 1999 355 None 235389
# Gone Hollie Smith Natural Wonders Music Sampler 1999 362 None 196414
# The Immigrant Joanie Madden Natural Wonders Music Sampler 1999 350 None 362631
# Pahrump-Big Water Cusco Natural Wonders Music Sampler 1999 342 None 191634
# Seeker's Quest Cheryl Gunn Natural Wonders Music Sampler 1999 337 None 236434
# Floating To Forever Dean Everson Natural Wonders Music Sampler 1999 337 None 351686
# Open Road Jeff Bailey Relaxing Jazz 10 None 318563
# Ruby Kaiser Chiefs Yours Truly, Angry Mob 13 None 205008
# The Angry Mob Kaiser Chiefs Yours Truly, Angry Mob 41 None 288313
# Heat Dies Down Kaiser Chiefs Yours Truly, Angry Mob 12 None 237061
# Highroyds Kaiser Chiefs Yours Truly, Angry Mob 10 None 199575
# Love's Not A Competition (But I'm Winning) Kaiser Chiefs Yours Truly, Angry Mob 11 None 197799
# Thank You Very Much Kaiser Chiefs Yours Truly, Angry Mob 11 None 157753
# I Can Do It Without You Kaiser Chiefs Yours Truly, Angry Mob 11 None 204199
# My Kind Of Guy Kaiser Chiefs Yours Truly, Angry Mob 10 None 246595
# Everything Is Average Nowadays Kaiser Chiefs Yours Truly, Angry Mob 16 None 164754
# Learnt My Lesson Well Kaiser Chiefs Yours Truly, Angry Mob 9 None 325955
# Try Your Best Kaiser Chiefs Yours Truly, Angry Mob 8 None 222511
# Retirement Kaiser Chiefs Yours Truly, Angry Mob 10 None 237426
# The Angry Mob [Live From Berlin] Kaiser Chiefs Yours Truly, Angry Mob 40 None 279066
# I Like To Fight Kaiser Chiefs Yours Truly, Angry Mob 8 None 218566
# From The Neck Down Kaiser Chiefs Yours Truly, Angry Mob 15 None 147226
# Bomb Squad (TECH) Brent Brent's Album 4 None 208065
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-32ba596f6ade> in <module>
#      82         VALUES ( ? )''', ( genre, ) )
#      83     cur.execute('SELECT id FROM Genre WHERE name = ? ', (genre, ))
# ---> 84     genre_id = cur.fetchone()[0]
#      85
#      86     cur.execute('''INSERT OR IGNORE INTO Album (title, artist_id)
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # json Data

# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
cur = conn.cursor()

# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

fname = input('Enter file name: ')
if len(fname) < 1:
    fname = 'roster_data.json'

# [
#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

str_data = open(fname).read()
json_data = json.loads(str_data)

for entry in json_data:

    name = entry[0];
    title = entry[1];
    role=entry[2];

    print((name, title,name))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id,role) VALUES ( ?, ? ,?)''',
        ( user_id, course_id,role ) )

    conn.commit()
# Out:
# Enter file name: roster_data.json
# ('Lois', 'si110', 'Lois')
# ('Corrina', 'si110', 'Corrina')
# ('Ciara', 'si110', 'Ciara')
# ('Anir', 'si110', 'Anir')
# ('Macaulay', 'si110', 'Macaulay')
# ('Conlan', 'si110', 'Conlan')
# ('Yishuka', 'si110', 'Yishuka')
# ('Manmohan', 'si110', 'Manmohan')
# ('Shula', 'si110', 'Shula')
# ('Sher', 'si110', 'Sher')
# ('Cobie', 'si110', 'Cobie')
# ('Maiah', 'si110', 'Maiah')
# ('Danniel', 'si110', 'Danniel')
# ('Monta', 'si110', 'Monta')
# ('Mariena', 'si110', 'Mariena')
# ('Mena', 'si110', 'Mena')
# ('Marriam', 'si110', 'Marriam')
# ('Carl', 'si110', 'Carl')
# ('Patsy', 'si106', 'Patsy')
# ('Cruz', 'si106', 'Cruz')
# ('Darian', 'si106', 'Darian')
# ('Bethanie', 'si106', 'Bethanie')
# ('Harjyot', 'si106', 'Harjyot')
# ('Latisha', 'si106', 'Latisha')
# ('Samuel', 'si106', 'Samuel')
# ('Marli', 'si106', 'Marli')
# ('Meyzhward', 'si106', 'Meyzhward')
# ('Lorne', 'si106', 'Lorne')
# ('Amera', 'si106', 'Amera')
# ('Vasiliki', 'si106', 'Vasiliki')
# ('Limo', 'si106', 'Limo')
# ('Zachariya', 'si106', 'Zachariya')
# ('Ehsen', 'si106', 'Ehsen')
# ('Aamirah', 'si106', 'Aamirah')
# ('Kaidyn', 'si106', 'Kaidyn')
# ('Kirie', 'si106', 'Kirie')
# ('Doone', 'si106', 'Doone')
# ('Katie', 'si106', 'Katie')
# ('Koray', 'si106', 'Koray')
# ('Hcen', 'si106', 'Hcen')
# ('Suzy', 'si106', 'Suzy')
# ('Stevey', 'si106', 'Stevey')
# ('Rayne', 'si106', 'Rayne')
# ('Shanelle', 'si106', 'Shanelle')
# ('Trey', 'si106', 'Trey')
# ('Hately', 'si106', 'Hately')
# ('Marin', 'si106', 'Marin')
# ('Chymari', 'si106', 'Chymari')
# ('Manal', 'si106', 'Manal')
# ('Rhylee', 'si106', 'Rhylee')
# ('Zubair', 'si106', 'Zubair')
# ('Lynsey', 'si106', 'Lynsey')
# ('Darragh', 'si106', 'Darragh')
# ('Cael', 'si106', 'Cael')
# ('Elyssa', 'si106', 'Elyssa')
# ('Malachi', 'si106', 'Malachi')
# ('Evalina', 'si106', 'Evalina')
# ('Garrett', 'si106', 'Garrett')
# ('Drew', 'si106', 'Drew')
# ('Jaheim', 'si106', 'Jaheim')
# ('Elis', 'si106', 'Elis')
# ('Scarlett', 'si106', 'Scarlett')
# ('Miranne', 'si206', 'Miranne')
# ('Riley', 'si206', 'Riley')
# ('Ragid', 'si206', 'Ragid')
# ('Eden', 'si206', 'Eden')
# ('Amyrose', 'si206', 'Amyrose')
# ('Lasse', 'si206', 'Lasse')
# ('Sheanne', 'si206', 'Sheanne')
# ('Wen', 'si206', 'Wen')
# ('Cillin', 'si206', 'Cillin')
# ('Kiefer', 'si206', 'Kiefer')
# ('Connan', 'si206', 'Connan')
# ('Lilya', 'si206', 'Lilya')
# ('Ellen', 'si206', 'Ellen')
# ('Callie', 'si206', 'Callie')
# ('Livie', 'si206', 'Livie')
# ('Isher', 'si206', 'Isher')
# ('Avani', 'si206', 'Avani')
# ('Enrique', 'si206', 'Enrique')
# ('Calean', 'si206', 'Calean')
# ('Jaksyn', 'si206', 'Jaksyn')
# ('Alishba', 'si206', 'Alishba')
# ('Magnus', 'si206', 'Magnus')
# ('Hayden', 'si301', 'Hayden')
# ('Andrejs', 'si301', 'Andrejs')
# ('Keiren', 'si301', 'Keiren')
# ('Dewi', 'si301', 'Dewi')
# ('Hansen', 'si301', 'Hansen')
# ('Eeman', 'si301', 'Eeman')
# ('Calin', 'si301', 'Calin')
# ('Caidie', 'si301', 'Caidie')
# ('Judah', 'si301', 'Judah')
# ('Bryden', 'si301', 'Bryden')
# ('Ian', 'si301', 'Ian')
# ('Meenal', 'si301', 'Meenal')
# ('Ceridwen', 'si301', 'Ceridwen')
# ('Guerin', 'si301', 'Guerin')
# ('Travis', 'si301', 'Travis')
# ('Maxie', 'si301', 'Maxie')
# ('Kari', 'si301', 'Kari')
# ('Torrie', 'si301', 'Torrie')
# ('Kieryn', 'si301', 'Kieryn')
# ('Katrina', 'si301', 'Katrina')
# ('Shae', 'si301', 'Shae')
# ('CJ', 'si301', 'CJ')
# ('Carlie', 'si301', 'Carlie')
# ('Favour', 'si301', 'Favour')
# ('Taylan', 'si301', 'Taylan')
# ('Elsa', 'si301', 'Elsa')
# ('Kyhran', 'si301', 'Kyhran')
# ('Kaylie', 'si310', 'Kaylie')
# ('Maighdlin', 'si310', 'Maighdlin')
# ('Siyona', 'si310', 'Siyona')
# ('Hollyanne', 'si310', 'Hollyanne')
# ('Dione', 'si310', 'Dione')
# ('Rhein', 'si310', 'Rhein')
# ('Valery', 'si310', 'Valery')
# ('Milos', 'si310', 'Milos')
# ('Trinity', 'si310', 'Trinity')
# ('Kaya', 'si310', 'Kaya')
# ('Arda', 'si310', 'Arda')
# ('Reeve', 'si310', 'Reeve')
# ('Aiva', 'si310', 'Aiva')
# ('Merab', 'si310', 'Merab')
# ('Jennah', 'si310', 'Jennah')
# ('Ramone', 'si310', 'Ramone')
# ('Ceridwen', 'si310', 'Ceridwen')
# ('Donnie', 'si310', 'Donnie')
# ('Jay', 'si310', 'Jay')
# ('Tomasz', 'si310', 'Tomasz')
# ('Lauren', 'si310', 'Lauren')
# ('Mirran', 'si310', 'Mirran')
# ('Kyren', 'si310', 'Kyren')
# ('Alisdair', 'si310', 'Alisdair')
# ('Jaime', 'si310', 'Jaime')
# ('Corie', 'si310', 'Corie')
# ('Abiya', 'si310', 'Abiya')
# ('Kaleena', 'si310', 'Kaleena')
# ('Afonso', 'si310', 'Afonso')
# ('Aanya', 'si310', 'Aanya')
# ('Cedar', 'si310', 'Cedar')
# ('Elias', 'si310', 'Elias')
# ('Evalina', 'si310', 'Evalina')
# ('Jaia', 'si310', 'Jaia')
# ('Sophie', 'si310', 'Sophie')
# ('Pyper', 'si334', 'Pyper')
# ('Faizaan', 'si334', 'Faizaan')
# ('Danielle', 'si334', 'Danielle')
# ('Boudicca', 'si334', 'Boudicca')
# ('Jazmin', 'si334', 'Jazmin')
# ('Kya', 'si334', 'Kya')
# ('Caroline', 'si334', 'Caroline')
# ('Kirie', 'si334', 'Kirie')
# ('Will', 'si334', 'Will')
# ('Mitchel', 'si334', 'Mitchel')
# ('Marcy', 'si334', 'Marcy')
# ('Nevaeh', 'si334', 'Nevaeh')
# ('Taylor', 'si334', 'Taylor')
# ('Cassia', 'si334', 'Cassia')
# ('Gracielynn', 'si334', 'Gracielynn')
# ('Joely', 'si334', 'Joely')
# ('Katelyne', 'si334', 'Katelyne')
# ('Jannat', 'si334', 'Jannat')
# ('Reilly', 'si334', 'Reilly')
# ('Atiya', 'si334', 'Atiya')
# ('Brenna', 'si334', 'Brenna')
# ('Danyil', 'si334', 'Danyil')
# ('Kenzii', 'si334', 'Kenzii')
# ('Reese', 'si334', 'Reese')
# ('Sandie', 'si334', 'Sandie')
# ('Linzi', 'si334', 'Linzi')
# ('Sidney', 'si334', 'Sidney')
# ('Mir', 'si334', 'Mir')
# ('Kaidy', 'si334', 'Kaidy')
# ('Allen', 'si334', 'Allen')
# ('Aleksandra', 'si334', 'Aleksandra')
# ('Daniyal', 'si334', 'Daniyal')
# ('Haris', 'si334', 'Haris')
# ('Colvin', 'si334', 'Colvin')
# ('Elena', 'si334', 'Elena')
# ('Zakk', 'si334', 'Zakk')
# ('Elsie', 'si334', 'Elsie')
# ('Teresa', 'si334', 'Teresa')
# ('Caileen', 'si334', 'Caileen')
# ('Kaedyn', 'si334', 'Kaedyn')
# ('Wilhelmina', 'si334', 'Wilhelmina')
# ('Yannick', 'si334', 'Yannick')
# ('Coll', 'si334', 'Coll')
# ('Aymal', 'si334', 'Aymal')
# ('Ashtyn', 'si363', 'Ashtyn')
# ('Jordanna', 'si363', 'Jordanna')
# ('Ellisha', 'si363', 'Ellisha')
# ('Brogan', 'si363', 'Brogan')
# ('Zakariya', 'si363', 'Zakariya')
# ('Natalie', 'si363', 'Natalie')
# ('Cali', 'si363', 'Cali')
# ('Pia', 'si363', 'Pia')
# ('Eugene', 'si363', 'Eugene')
# ('Cephas', 'si363', 'Cephas')
# ('Daegyu', 'si363', 'Daegyu')
# ('Nico', 'si363', 'Nico')
# ('Derin', 'si363', 'Derin')
# ('Koby', 'si363', 'Koby')
# ('Alan', 'si363', 'Alan')
# ('Kassey', 'si363', 'Kassey')
# ('Rossi', 'si363', 'Rossi')
# ('Adrian', 'si363', 'Adrian')
# ('Justine', 'si363', 'Justine')
# ('Kasey', 'si363', 'Kasey')
# ('Igor', 'si363', 'Igor')
# ('Zoha', 'si363', 'Zoha')
# ('Fodeba', 'si363', 'Fodeba')
# ('Rhuaridh', 'si363', 'Rhuaridh')
# ('Bracken', 'si363', 'Bracken')
# ('Mohammad', 'si363', 'Mohammad')
# ('Christoph', 'si363', 'Christoph')
# ('Liall', 'si363', 'Liall')
# ('Padraig', 'si363', 'Padraig')
# ('Rennie', 'si363', 'Rennie')
# ('Kyron', 'si363', 'Kyron')
# ('Mutinta', 'si363', 'Mutinta')
# ('Ricco', 'si363', 'Ricco')
# ('Leighton', 'si363', 'Leighton')
# ('Bill', 'si363', 'Bill')
# ('Stuart', 'si363', 'Stuart')
# ('Yusuf', 'si363', 'Yusuf')
# ('Easton', 'si363', 'Easton')
# ('Jumaimah', 'si363', 'Jumaimah')
# ('Fiza', 'si363', 'Fiza')
# ('Jarl', 'si363', 'Jarl')
# ('Muzzammil', 'si363', 'Muzzammil')
# ('Emilie', 'si363', 'Emilie')
# ('Sharleen', 'si363', 'Sharleen')
# ('Shaurya', 'si364', 'Shaurya')
# ('Ami', 'si364', 'Ami')
# ('Zunaira', 'si364', 'Zunaira')
# ('Siriol', 'si364', 'Siriol')
# ('Christie', 'si364', 'Christie')
# ('Kaidan', 'si364', 'Kaidan')
# ('Mylo', 'si364', 'Mylo')
# ('Subhaan', 'si364', 'Subhaan')
# ('Amez', 'si364', 'Amez')
# ('Banan', 'si364', 'Banan')
# ('Nikela', 'si364', 'Nikela')
# ('Isa', 'si364', 'Isa')
# ('Niro', 'si364', 'Niro')
# ('Orlaigh', 'si364', 'Orlaigh')
# ('Isla', 'si364', 'Isla')
# ('Thorben', 'si364', 'Thorben')
# ('Abril', 'si364', 'Abril')
# ('Caiden', 'si364', 'Caiden')
# ('Rhythm', 'si364', 'Rhythm')
# ('Iyanuoluwa', 'si364', 'Iyanuoluwa')
# ('Ata', 'si364', 'Ata')
# ('Meagan', 'si364', 'Meagan')
# ('Fatimah', 'si364', 'Fatimah')
# ('Maeghan', 'si364', 'Maeghan')
# ('Rexford', 'si364', 'Rexford')
# ('Thia', 'si364', 'Thia')
# ('Reuben', 'si364', 'Reuben')
# ('Shikha', 'si364', 'Shikha')
# ('Wynn', 'si364', 'Wynn')
# ('Doire', 'si364', 'Doire')
# ('Arella', 'si364', 'Arella')
# ('Mohammed', 'si364', 'Mohammed')
# ('Teiyib', 'si364', 'Teiyib')
# ('Keigan', 'si364', 'Keigan')
# ('Blair', 'si422', 'Blair')
# ('Chantelle', 'si422', 'Chantelle')
# ('Cole', 'si422', 'Cole')
# ('Aaron', 'si422', 'Aaron')
# ('Prabhjoit', 'si422', 'Prabhjoit')
# ('Seriah', 'si422', 'Seriah')
# ('Keiron', 'si422', 'Keiron')
# ('Marty', 'si422', 'Marty')
# ('Jordyn', 'si422', 'Jordyn')
# ('Cori', 'si422', 'Cori')
# ('Kaidenn', 'si422', 'Kaidenn')
# ('Markus', 'si422', 'Markus')
# ('Bryce', 'si422', 'Bryce')
# ('Parmin', 'si422', 'Parmin')
# ('Ruqayah', 'si422', 'Ruqayah')
# ('Karlie', 'si422', 'Karlie')
# ('Corbin', 'si422', 'Corbin')
# ('Sohaa', 'si422', 'Sohaa')
# ('Kaela', 'si422', 'Kaela')
# ('Jesutobiloba', 'si422', 'Jesutobiloba')
# ('Ruaridh', 'si422', 'Ruaridh')
# ('Aleksander', 'si422', 'Aleksander')
# ('Ellisandro', 'si422', 'Ellisandro')
# ('Carson', 'si422', 'Carson')
# ('Siubhan', 'si422', 'Siubhan')
# ('Melica', 'si422', 'Melica')
# ('Ka', 'si422', 'Ka')
# ('Eoghan', 'si422', 'Eoghan')
# ('Carrick', 'si422', 'Carrick')
# ('Rhy', 'si422', 'Rhy')
# ('Mariyah', 'si422', 'Mariyah')
# ('Zara', 'si422', 'Zara')
# ('Teri', 'si422', 'Teri')
# ('Caitlin', 'si422', 'Caitlin')
# ('Torin', 'si422', 'Torin')
# ('Shanea', 'si422', 'Shanea')
# ('Ricards', 'si422', 'Ricards')
# ('Jeswin', 'si422', 'Jeswin')
# ('Sharoz', 'si422', 'Sharoz')
# ('Oscar', 'si422', 'Oscar')
# ('Prasheeta', 'si422', 'Prasheeta')
# ('Cree', 'si422', 'Cree')
# ('Gian', 'si422', 'Gian')
# ('Khyla', 'si422', 'Khyla')
# ('Marwah', 'si422', 'Marwah')
# ('Haleema', 'si422', 'Haleema')
# ('Mehreen', 'si422', 'Mehreen')
# ('Caidy', 'si422', 'Caidy')
# ('Rona', 'si422', 'Rona')
# ('Irfa', 'si430', 'Irfa')
# ('Fatiha', 'si430', 'Fatiha')
# ('Kinza', 'si430', 'Kinza')
# ('Naideen', 'si430', 'Naideen')
# ('Wyatt', 'si430', 'Wyatt')
# ('Kelam', 'si430', 'Kelam')
# ('Adalaide', 'si430', 'Adalaide')
# ('Angeline', 'si430', 'Angeline')
# ('Isabelle', 'si430', 'Isabelle')
# ('Madison', 'si430', 'Madison')
# ('Aelish', 'si430', 'Aelish')
# ('Menna', 'si430', 'Menna')
# ('Jennah', 'si430', 'Jennah')
# ('Charlene', 'si430', 'Charlene')
# ('Plamedie', 'si430', 'Plamedie')
# ('Anwen', 'si430', 'Anwen')
# ('Zita', 'si430', 'Zita')
# ('Jarell', 'si430', 'Jarell')
# ('Bryn', 'si430', 'Bryn')
# ('Johnny', 'si430', 'Johnny')
# ('Elivia', 'si430', 'Elivia')
# ('Seonaidh', 'si430', 'Seonaidh')
# ('Ellia', 'si430', 'Ellia')
# ('Arya', 'si430', 'Arya')

# %% [markdown]
# # Python Geo

# %%
import urllib.request, urllib.parse, urllib.error
import http
import sqlite3
import json
import time
import ssl
import sys

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'

if api_key is False:
    api_key = 42
    serviceurl = "http://py4e-data.dr-chuck.net/json?"
else :
    serviceurl = "https://maps.googleapis.com/maps/api/geocode/json?"

# Additional detail for urllib
# http.client.HTTPConnection.debuglevel = 1

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

fh = open("where.data")
count = 0
for line in fh:
    if count > 200 :
        print('Retrieved 200 locations, restart to retrieve more')
        break

    address = line.strip()
    print('')
    cur.execute("SELECT geodata FROM Locations WHERE address= ?",
        (memoryview(address.encode()), ))

    try:
        data = cur.fetchone()[0]
        print("Found in database ",address)
        continue
    except:
        pass

    parms = dict()
    parms["address"] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters', data[:20].replace('\n', ' '))
    count = count + 1

    try:
        js = json.loads(data)
    except:
        print(data)  # We print in case unicode causes an error
        continue

    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') :
        print('==== Failure To Retrieve ====')
        print(data)
        break

    cur.execute('''INSERT INTO Locations (address, geodata)
            VALUES ( ?, ? )''', (memoryview(address.encode()), memoryview(data.encode()) ) )
    conn.commit()
    if count % 10 == 0 :
        print('Pausing for a bit...')
        time.sleep(5)

print("Run geodump.py to read the data from the database so you can vizualize it on a map.")
# Out:
# Retrieving http://py4e-data.dr-chuck.net/json?address=AGH+University+of+Science+and+Technology&key=42
# Retrieved 2315 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Academy+of+Fine+Arts+Warsaw+Poland&key=42
# Retrieved 2006 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=American+University+in+Cairo&key=42
# Retrieved 1828 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Anna+University+in+Chennai&key=42
# Retrieved 2207 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Arizona+State+University&key=42
# Retrieved 1802 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Athens+Information+Technology&key=42
# Retrieved 2274 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=BITS+Pilani&key=42
# Retrieved 1807 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Babcock+University&key=42
# Retrieved 1633 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Banaras+Hindu+University&key=42
# Retrieved 1989 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bangalore+University&key=42
# Retrieved 2188 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Baylor+University&key=42
# Retrieved 2102 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Beijing+normal+university&key=42
# Retrieved 2209 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belarusian+State+University&key=42
# Retrieved 2184 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belgrade+University&key=42
# Retrieved 1944 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Beloit+College&key=42
# Retrieved 2265 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belorussian+State+University&key=42
# Retrieved 4542 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ben+Gurion+University&key=42
# Retrieved 1927 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bharthidasan+University&key=42
# Retrieved 1893 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Boston+University&key=42
# Retrieved 2003 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=California+Polytechnic+State+University+of+San+Luis+Obispo&key=42
# Retrieved 1860 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=California+State+University+San+Bernardino&key=42
# Retrieved 2182 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=City+of+Westminster+College&key=42
# Retrieved 2120 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Columbia+University&key=42
# Retrieved 1996 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Cranfield+University&key=42
# Retrieved 2167 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Czech+Technical+University+in+Prague&key=42
# Retrieved 1821 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dartmouth&key=42
# Retrieved 2163 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=De+Anza+College&key=42
# Retrieved 2172 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Distant+University+of+Hagen&key=42
# Retrieved 2100 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dnipropetrovsk+National+University&key=42
# Retrieved 2442 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dokuz+Eylul+University&key=42
# Retrieved 2127 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Drexel&key=42
# Retrieved 2351 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Drexel+University+and+University+of+Texas+at+Austin&key=42
# Retrieved 1795 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Duke+University&key=42
# Retrieved 1993 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=EM+Lyon&key=42
# Retrieved 4389 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ecole+centrale+de+PARIS&key=42
# Retrieved 2326 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Elon+University&key=42
# Retrieved 2323 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Erhvervsakademi+Sydvest&key=42
# Retrieved 1765 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Escuela+Superior+Politecnica+del+Litoral&key=42
# Retrieved 4267 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Fachhochschule+Dusseldorf&key=42
# Retrieved 2355 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Fachhochschule+FH+Salzburg&key=42
# Retrieved 2110 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Faculdade+de+Tecnologia+do+Estado+de+Sao+Paulo&key=42
# Retrieved 2200 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Faculty+of+Technical+Sciences+Novi+Sad+Serbia&key=42
# Retrieved 2130 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Farmingdale+State+University&key=42
# Retrieved 2133 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Federal+University+of+Minas+Gerais&key=42
# Retrieved 2253 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Florida+Atlantic+University&key=42
# Retrieved 2137 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Franklin+Pierce+College&key=42
# Retrieved 2292 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Gauhati+University&key=42
# Retrieved 2026 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=George+Mason+University&key=42
# Retrieved 2313 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Georgetown+University+Law+Center&key=42
# Retrieved 2187 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Georgia+State+University&key=42
# Retrieved 1994 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Grandville&key=42
# Retrieved 1752 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Groep+T+University&key=42
# Retrieved 4138 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Hanoi+University+of+Science+and+Technology&key=42
# Retrieved 1823 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Hebrew+University&key=42
# Retrieved 1248 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IIIT+Hyderabad&key=42
# Retrieved 2233 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IIT+KANPUR&key=42
# Retrieved 2029 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IT+College+of+Estonia&key=42
# Retrieved 2089 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IU&key=42
# Retrieved 2314 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IUAV+Venezia&key=42
# Retrieved 2306 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Illinois+Institute+of+Technology&key=42
# Retrieved 2275 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Illinois+State+University+Joliet+Junior+College&key=42
# Retrieved 2345 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology&key=42
# Retrieved 2198 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology+Kharagpur+India&key=42
# Retrieved 1817 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+School+of+Mines+Dhanbad&key=42
# Retrieved 2600 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indiana+University&key=42
# Retrieved 2314 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indiana+University+at+Bloomington&key=42
# Retrieved 2314 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Institut+Superieur+de+technologies&key=42
# Retrieved 4373 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Institute+of+Business+and+Modern+Technologies&key=42
# Retrieved 4421 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Instituto+Tecnologico+de+Santo+Domingo&key=42
# Retrieved 2423 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=International+Institute+of+Information+Technology+Hyderabad&key=42
# Retrieved 2233 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Irkutsk+State+University&key=42
# Retrieved 4266 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=JADAVPUR+UNIVERSITY&key=42
# Retrieved 2159 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+Technological+University&key=42
# Retrieved 4828 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+University&key=42
# Retrieved 1966 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jordan+University+of+Science+and+Technology&key=42
# Retrieved 1474 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=K-State&key=42
# Retrieved 1807 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=KUL&key=42
# Retrieved 4913 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kalamazoo+College&key=42
# Retrieved 2313 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kaunas+Technology+University&key=42
# Retrieved 2139 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kaunas+university+of+technology&key=42
# Retrieved 2120 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kazan+Federal+University&key=42
# Retrieved 2350 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kent+State+University&key=42
# Retrieved 2120 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kharkiv+State+Academy+of+Municipal+Economy+Ukraine&key=42
# Retrieved 1765 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=King+Mongkuts+University+of+Technology+Thonburi&key=42
# Retrieved 2247 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kokshetau+Institute+of+Economics+and+Management&key=42
# Retrieved 1967 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnic+Institute&key=42
# Retrieved 2127 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnical+Institute&key=42
# Retrieved 2160 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Unisersity+of+Oriental+Language&key=42
# Retrieved 1699 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Laurentian+University&key=42
# Retrieved 2357 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lisandro+Alvarado&key=42
# Retrieved 52 characters {    "results" : [],
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lodz+University+of+Technology&key=42
# Retrieved 2292 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lviv+University&key=42
# Retrieved 2379 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=MSU&key=42
# Retrieved 2162 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Madras+university&key=42
# Retrieved 2419 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Magnitogorsk+State+Technical+University&key=42
# Retrieved 2209 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Malayer+Azad+University&key=42
# Retrieved 1663 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Marietta+College&key=42
# Retrieved 4343 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Masdar+Institute&key=42
# Retrieved 1733 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Matematicki+fakultet+Beograd&key=42
# Retrieved 2107 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Michigan+State+University&key=42
# Retrieved 2162 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Middle+East+Technical+University&key=42
# Retrieved 2350 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Missouri+University+of+Science+and+Technology&key=42
# Retrieved 2485 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash&key=42
# Retrieved 1969 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash+University&key=42
# Retrieved 1969 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash+University+Churchill+Australia&key=42
# Retrieved 3906 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monterrey+Institute+of+Technology+and+Higher+Education&key=42
# Retrieved 2187 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+Engineering-Physics+Institute&key=42
# Retrieved 2375 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+Institute+of+Physics+%26+Technology&key=42
# Retrieved 2189 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+State+University&key=42
# Retrieved 2136 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=NIT+ROURKELA&key=42
# Retrieved 2540 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=NYU&key=42
# Retrieved 4295 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Nagpur+University&key=42
# Retrieved 4279 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Nanyang+Technological+University&key=42
# Retrieved 1620 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+Institute+of+Technology+Jalandhar&key=42
# Retrieved 2029 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+Taiwan+University&key=42
# Retrieved 2017 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+University+of+Engineering&key=42
# Retrieved 1882 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=North+Central+College&key=42
# Retrieved 2533 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Northeastern+University&key=42
# Retrieved 2322 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Northwestern+University&key=42
# Retrieved 2130 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Obninsk+Technical+University+of+Nuclear+Power+Engineering+Russia&key=42
# Retrieved 2175 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Old+Dominion+University&key=42
# Retrieved 1931 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Oregon+Institute+of+Technology&key=42
# Retrieved 2138 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=PUCMM&key=42
# Retrieved 2213 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Payame+Noor+University&key=42
# Retrieved 1843 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Penn+State+University&key=42
# Retrieved 1843 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Politecnico+di+Milano&key=42
# Retrieved 2345 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Politehnica+University+Bucharest&key=42
# Retrieved 2365 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Polytechnic+University+of+Timisoara&key=42
# Retrieved 2124 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Pondicherry+University&key=42
# Retrieved 2226 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Pontificia+universidad+catolica+de+chile&key=42
# Retrieved 2248 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Portland+State+University&key=42
# Retrieved 2475 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Purdue+University+Indianapolis&key=42
# Retrieved 2352 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=R+V+College+of+Engineering&key=42
# Retrieved 2387 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=RPI&key=42
# Retrieved 2106 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ramapo+College+of+New+Jersey&key=42
# Retrieved 2286 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Rochester+Institute+of+Technology&key=42
# Retrieved 2484 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=SASTRA+University&key=42
# Retrieved 1854 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University&key=42
# Retrieved 2193 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University+of+Aerospace+Instrumentation&key=42
# Retrieved 2196 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint-Petersburg+Polytechnic+Univesity&key=42
# Retrieved 2228 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=San+Francisco+State+University&key=42
# Retrieved 2330 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=San+Jose+State+University&key=42
# Retrieved 2311 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Shanghai+Jiao+Tong+University&key=42
# Retrieved 1668 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Sharif+University+of+Technology&key=42
# Retrieved 1471 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Simon+Bolivar+University&key=42
# Retrieved 1658 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Simon+Fraser+University&key=42
# Retrieved 2144 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Smolensk+State+University&key=42
# Retrieved 4322 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Sonoma+State+University&key=42
# Retrieved 2152 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=South+Federal+University&key=42
# Retrieved 2291 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Spiru+Haret+University&key=42
# Retrieved 2347 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stanford&key=42
# Retrieved 1928 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=State+University+of+Campinas&key=42
# Retrieved 2102 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=State+University+of+New+York+College+at+Oswego&key=42
# Retrieved 2114 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stellenbosch+University&key=42
# Retrieved 1903 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stonehill+College&key=42
# Retrieved 2319 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tallinn+University&key=42
# Retrieved 2139 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tallinn+University+of+Technology&key=42
# Retrieved 2116 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tampere+University+of+Technology&key=42
# Retrieved 1441 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tanta+University&key=42
# Retrieved 1870 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tarrant+County+College&key=42
# Retrieved 4419 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Technical+University+of+Cluj-Napoca&key=42
# Retrieved 2158 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Technion&key=42
# Retrieved 1702 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tel+Aviv+University&key=42
# Retrieved 1474 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+Jerusalem+collage+of+engineering&key=42
# Retrieved 2407 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+Latvia&key=42
# Retrieved 1946 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+Manchester&key=42
# Retrieved 1978 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+South+Africa&key=42
# Retrieved 2229 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Transilvania+University&key=42
# Retrieved 2322 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tufts+University&key=42
# Retrieved 2130 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UC+Berkeley&key=42
# Retrieved 1741 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UCLA&key=42
# Retrieved 2006 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UCSD&key=42
# Retrieved 2302 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UIUC&key=42
# Retrieved 1689 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UMD&key=42
# Retrieved 2467 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UNISA&key=42
# Retrieved 2463 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UNIVERSIDAD+DE+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UOC&key=42
# Retrieved 2110 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=USC&key=42
# Retrieved 2022 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UW+Madison&key=42
# Retrieved 1649 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Central+de+Venezuela&key=42
# Retrieved 1678 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Complutense+de+Madrid&key=42
# Retrieved 4126 characters {    "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Cooperativa+de+Colombia&key=42
# Retrieved 1825 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Autonoma+de+Mexico&key=42
# Retrieved 2165 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Costa+Rica&key=42
# Retrieved 1664 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+de+Colombia&key=42
# Retrieved 3998 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Tecnologica+Boliviana&key=42
# Retrieved 4188 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Castilla+La+Mancha&key=42
# Retrieved 2157 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Los+Andes+Colombia&key=42
# Retrieved 2081 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Oriente&key=42
# Retrieved 2213 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+San+Carlos+de+Guatemala&key=42
# Retrieved 2147 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Valladolid&key=42
# Retrieved 2118 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+la+Sabana&key=42
# Retrieved 1794 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+del+Valle+de+Guatemala&key=42
# Retrieved 2021 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+da+Paraiba&key=42
# Retrieved 1928 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+de+Santa+Catarina&key=42
# Retrieved 2316 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+Grande+do+Sul&key=42
# Retrieved 2230 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+de+Janeiro&key=42
# Retrieved 2400 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Tecnica+de+Lisboa&key=42
# Retrieved 1920 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+de+Sao+Paulo&key=42
# Retrieved 1703 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+do+Minho&key=42
# Retrieved 1782 characters {    "results" : [
# Retrieved 200 locations, restart to retrieve more
# Run geodump.py to read the data from the database so you can vizualize it on a map.

# %%
import sqlite3
import json
import codecs

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('SELECT * FROM Locations')
fhand = codecs.open('where.js', 'w', "utf-8")
fhand.write("myData = [\n")
count = 0
for row in cur :
    data = str(row[1].decode())
    try: js = json.loads(str(data))
    except: continue

    if not('status' in js and js['status'] == 'OK') : continue

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    if lat == 0 or lng == 0 : continue
    where = js['results'][0]['formatted_address']
    where = where.replace("'", "")
    try :
        print(where, lat, lng)

        count = count + 1
        if count > 1 : fhand.write(",\n")
        output = "["+str(lat)+","+str(lng)+", '"+where+"']"
        fhand.write(output)
    except:
        continue

fhand.write("\n];\n")
cur.close()
fhand.close()
print(count, "records written to where.js")
print("Open where.html to view the data in a browser")
# Out:
# aleja Adama Mickiewicza 30, 30-059 Kraków, Poland 50.06688579999999 19.9136192
# Krakowskie Przedmieście 5, 00-068 Warszawa, Poland 52.2394019 21.0150792
# AUC Avenue، Road، First New Cairo, Cairo Governorate 11835, Egypt 30.018923 31.499674
# Anna University, Guindy, Chennai, Tamil Nadu 600025, India 13.0108831 80.2353768
# Tempe, AZ 85281, USA 33.4242399 -111.9280527
# 2500 Daniells Bridge Rd #300, Athens, GA 30606, USA 33.9094132 -83.4603953
# Vidya Vihar, Pilani, Rajasthan 333031, India 28.3588163 75.58802039999999
# Ilishan-Remo, Nigeria 6.8939569 3.7187158
# Ajagara, Varanasi, Uttar Pradesh 221005, India 25.2677203 82.99125819999999
# Main Rd, Gnana Bharathi, Bengaluru, Karnataka 560056, India 12.9504351 77.5021998
# 1311 S 5th St, Waco, TX 76706, USA 31.5469111 -97.121151
# 19 Xinjiekou Outer St, Bei Tai Ping Zhuang, Haidian Qu, Beijing Shi, China, 100875 39.9619537 116.3662615
# praspiekt Niezaliežnasci 4, Minsk, Belarus 53.8938988 27.5460609
# Studentski trg 1, Beograd, Serbia 44.8184518 20.4575913
# 700 College St, Beloit, WI 53511, USA 42.5030333 -89.0309048
# praspiekt Niezaliežnasci 4, Minsk, Belarus 53.8938988 27.5460609
# שד בן-גוריון 1, באר שבע, Israel 31.262218 34.801461
# Palkalaiperur, Tiruchirappalli, Tamil Nadu 620024, India 10.6779085 78.74454879999999
# Boston, MA 02215, USA 42.3504997 -71.1053991
# San Luis Obispo, CA 93407, USA 35.3050053 -120.6624942
# 5500 University Pkwy, San Bernardino, CA 92407, USA 34.1817955 -117.3237219
# 25 Paddington Green, London W2 1NB, UK 51.5210038 -0.1746353
# New York, NY 10027, USA 40.8075355 -73.9625727
# College Rd, Cranfield, Wharley End, Bedford MK43 0AL, UK 52.0746136 -0.6282833
# 166 36 Prague 6, Czechia 50.1030364 14.3912841
# Hanover, NH 03755, USA 43.7044406 -72.2886935
# 21250 Stevens Creek Blvd, Cupertino, CA 95014, USA 37.3206678 -122.0454878
# Universitätsstraße 47, 58097 Hagen, Germany 51.377409 7.4921548
# Haharina Ave, 72, Dnipropetrovsk, Dnipropetrovska oblast, Ukraine, 49000 48.4331922 35.0427966
# Kültür, Cumhuriyet Blv No:144, 35220 Konak/İzmir, Turkey 38.4306911 27.1369201
# 3141 Chestnut St, Philadelphia, PA 19104, USA 39.9566127 -75.18994409999999
# Austin, TX 78712, USA 30.2849185 -97.7340567
# Durham, NC 27708, USA 36.0014258 -78.9382286
# 23 Avenue Guy de Collongue, 69130 Écully, France 45.7864448 4.7641329
# CentraleSupélec, 3 Rue Joliot Curie, 91190 Gif-sur-Yvette, France 48.7087594 2.1640062
# 50 Campus Drive, Elon, NC 27244, USA 36.1026877 -79.5023313
# Spangsbjerg Kirkevej 103, 6700 Esbjerg, Denmark 55.48843069999999 8.4467103
# Vía Perimetral 5, Guayaquil, Ecuador -2.1481458 -79.9644885
# Münsterstraße 156, 40476 Düsseldorf, Germany 51.2468622 6.791686899999999
# Urstein Süd 1, 5412 Puch bei Hallein, Austria 47.7233835 13.0871253
# Av. Tiradentes, 615 - Bom Retiro, São Paulo - SP, 01124-060, Brazil -23.5295777 -46.6325629
# Trg Dositeja Obradovića 6, Novi Sad 106314, Serbia 45.2461012 19.8516968
# 2350 NY-110, Farmingdale, NY 11735, USA 40.7529512 -73.4267093
# Av. Pres. Antônio Carlos, 6627 - Pampulha, Belo Horizonte - MG, 31270-901, Brazil -19.870682 -43.9677359
# 777 Glades Rd, Boca Raton, FL 33431, USA 26.3749876 -80.10106329999999
# 40 University Dr, Rindge, NH 03461, USA 42.7790898 -72.05560229999999
# Jalukbari, Guwahati, Assam 781014, India 26.1543199 91.66316789999999
# 4400 University Dr, Fairfax, VA 22030, USA 38.8298118 -77.3073606
# 600 New Jersey Ave NW, Washington, DC 20001, USA 38.8977953 -77.0129087
# Atlanta, GA 30302, USA 33.753068 -84.38528190000001
# Grandville, MI, USA 42.9097484 -85.7630885
# Oude Markt 13, 3000 Leuven, Belgium 50.87795449999999 4.7002953
# 1 Đại Cồ Việt, Bách Khoa, Hai Bà Trưng, Hà Nội, Vietnam 21.0048067 105.8453406
# Jerusalem 31.7945578 35.2414009
# Professor CR Rao Rd, Gachibowli, Hyderabad, Telangana 500032, India 17.4448019 78.3497604
# Kalyanpur, Kanpur, Uttar Pradesh 208016, India 26.5123388 80.2329
# Raja 4, 12616 Tallinn, Estonia 59.3954769 24.6643815
# 107 S Indiana Ave, Bloomington, IN 47405, USA 39.1754487 -86.512627
# Santa Croce, 191, 30135 Venezia VE, Italy 45.4377642 12.3226561
# 10 W 35th St, Chicago, IL 60616, USA 41.8348731 -87.6270059
# 100 N University St, Normal, IL 61761, USA 40.5120479 -88.9931683
# IIT Campus, Hauz Khas, New Delhi, Delhi 110016, India 28.5449756 77.19262839999999
# Kharagpur, West Bengal 721302, India 22.3149274 87.31053109999999
# Police Line Rd, IIT (ISM, Hirapur, Sardar Patel Nagar, Dhanbad, Jharkhand 826004, India 23.8143819 86.44120219999999
# 107 S Indiana Ave, Bloomington, IN 47405, USA 39.1754487 -86.512627
# 107 S Indiana Ave, Bloomington, IN 47405, USA 39.1754487 -86.512627
# 3230 Rue Sicotte, Saint-Hyacinthe, QC J2S 2M2, Canada 45.618372 -72.9675991
# 2400 Walsh Ave, Santa Clara, CA 95051, USA 37.3686167 -121.9695133
# Av. de Los Próceres 49, Santo Domingo 10602, Dominican Republic 18.487876 -69.96229199999999
# Professor CR Rao Rd, Gachibowli, Hyderabad, Telangana 500032, India 17.4448019 78.3497604
# Karl Marx St, 1, Irkutsk, Irkutskaya oblast, Russia, 664003 52.2766124 104.2777287
# Jadavpur university gate, 3, Jadavpur, Kolkata, West Bengal 700032, India 22.4988822 88.3714123
# Ashok Nagar, Kukatpally Housing Board Colony, Kukatpally, Hyderabad, Telangana 500085, India 17.4932682 78.3913929
# New Mehrauli Road, JNU Ring Rd, New Delhi, Delhi 110067, India 28.5402232 77.1662154
# Ar Ramtha 3030، Ar-Ramtha, Jordan 32.4950392 35.9912257
# Manhattan, KS 66506, USA 39.1974437 -96.5847249
# 1 Hospital Dr, Columbia, MO 65212, USA 38.938273 -92.3273842
# 1200 Academy St, Kalamazoo, MI 49006, USA 42.290035 -85.598145
# K. Baršausko g. 59, Kaunas 51423, Lithuania 54.89951019999999 23.9615303
# K. Donelaičio g. 73, Kaunas 44249, Lithuania 54.898991 23.912825
# Kremlyovskaya St, 18, Kazan, Respublika Tatarstan, Russia, 420008 55.790447 49.1214349
# 800 E Summit St, Kent, OH 44240, USA 41.1455594 -81.33928829999999
# Kharkiv, Kharkiv Oblast, Ukraine 49.9935 36.230383
# 126 Pracha Uthit Rd, Khwaeng Bang Mot, Khet Thung Khru, Krung Thep Maha Nakhon 10140, Thailand 13.6510248 100.4953802
# Kokshetau 020000, Kazakhstan 53.2871307 69.40444939999999
# Peremohy Ave, 37, Kyiv, Ukraine, 03056 50.4491694 30.4561475
# Peremohy Ave, 37, Kyiv, Ukraine, 03056 50.4491694 30.4561475
# Kyiv, Ukraine, 02000 50.4501 30.5234
# 935 Ramsey Lake Rd, Sudbury, ON P3E 2C6, Canada 46.4667708 -80.9742332
# Stefana Żeromskiego 116, 90-924 Łódź, Poland 51.7537146 19.4517176
# Universytetska St, 1, Lviv, Lvivska oblast, Ukraine, 79000 49.8406108 24.0225099
# 220 Trowbridge Rd, East Lansing, MI 48824, USA 42.701848 -84.4821719
# Navalar Nagar, Chepauk, Triplicane, Chennai, Tamil Nadu 600005, India 13.0660293 80.28317190000001
# Prospekt Lenina, 38, Magnitogorsk, Chelyabinskaya oblast, Russia, 455000 53.4222397 58.9824868
# Hamadan Province, Malayer, University Blvd, Iran 34.304073 48.8452846
# 215 5th St, Marietta, OH 45750, USA 39.41665649999999 -81.44993509999999
# Near Home WTC AUH, Airport Road - Masdar City - Abu Dhabi - United Arab Emirates 24.4330231 54.619113
# Studentski trg 16, Beograd 105104, Serbia 44.8199188 20.4587075
# 220 Trowbridge Rd, East Lansing, MI 48824, USA 42.701848 -84.4821719
# Üniversiteler, Dumlupinar Bulvari 1/6-133, 06800 Çankaya/Ankara, Turkey 39.88983820000001 32.780086
# 106, Parker Hall, 300 W 13th St, Rolla, MO 65409, USA 37.9537078 -91.7756271
# Wellington Rd, Clayton VIC 3800, Australia -37.9105599 145.1362485
# Wellington Rd, Clayton VIC 3800, Australia -37.9105599 145.1362485
# Northways Rd, Churchill VIC 3842, Australia -38.311211 146.429409
# Av. Eugenio Garza Sada 2501 Sur, Tecnológico, 64849 Monterrey, N.L., Mexico 25.6515649 -100.28954
# Kashira Hwy, 31, Moskva, Russia, 115409 55.6502051 37.6643098
# Institutskiy Pereulok, 9, Dolgoprudny, Moskovskaya oblast, Russia, 141701 55.9297243 37.5199434
# ul. Leninskiye Gory, 1, Moskva, Russia, 119991 55.70393490000001 37.5286696
# National Institute of Technology , Rourkela, National Institute of Technology, Sector 1, Rourkela, Odisha 769008, India 22.2533781 84.9012363
# New York, NY 10003, USA 40.72951339999999 -73.9964609
# Amravati Rd, Ram Nagar, Nagpur, Maharashtra 440033, India 21.1468555 79.050062
# 50 Nanyang Ave, Singapore 639798 1.3483099 103.6831347
# Grand Trunk Road, Barnala - Amritsar Bypass Rd, Jalandhar, Punjab 144011, India 31.395929 75.535856
# No. 1, Section 4, Roosevelt Rd, Da’an District, Taipei City, Taiwan 10617 25.0173405 121.5397518
# Avenida Tupac Amaru 210 Apartado 1301, Rímac 15333, Peru -12.0237376 -77.04837739999999
# 30 N Brainard St, Naperville, IL 60540, USA 41.772663 -88.1440142
# 360 Huntington Ave, Boston, MA 02115, USA 42.3398067 -71.0891717
# 633 Clark St, Evanston, IL 60208, USA 42.0564594 -87.67526699999999
# Студенческий городок, 1, Obninsk, Kaluzhskaya oblast, Russia, 249034 55.1372019 36.6064735
# 5115 Hampton Blvd, Norfolk, VA 23529, USA 36.8841106 -76.304239
# 3201 Campus Dr, Klamath Falls, OR 97601, USA 42.2573474 -121.7849109
# Autopista Duarte Km 1 1/2, Santiago De Los Caballeros 51000, Dominican Republic 19.4436005 -70.6843785
# Tehran Province, Tehran, اتوبان ارتش کوی نفت, Nakhl St, Iran 35.8012314 51.5028533
# State College, PA 16801, USA 40.7982133 -77.8599084
# Piazza Leonardo da Vinci, 32, 20133 Milano MI, Italy 45.4784315 9.228342399999999
# Splaiul Independenței 313, București 060042, Romania 44.4386064 26.0494925
# Piața Victoriei 2, Timișoara 300006, Romania 45.7536393 21.2251615
# Pondicherry University, Chinna Kalapet, Kalapet, Puducherry 605014, India 12.0182619 79.8568461
# Av Libertador Bernardo OHiggins 340, Santiago, Región Metropolitana, Chile -33.44180680000001 -70.6399544
# 1825 SW Broadway, Portland, OR 97201, USA 45.5111471 -122.6834235
# 420 University Blvd, Indianapolis, IN 46202, USA 39.77435 -86.1763446
# Mysore Rd, RV Vidyaniketan, Post, Bengaluru, Karnataka 560059, India 12.9237228 77.4987012
# 110 8th St, Troy, NY 12180, USA 42.7297628 -73.67888839999999
# 505 Ramapo Valley Rd, Mahwah, NJ 07430, USA 41.0819323 -74.1758157
# 1 Lomb Memorial Dr, Rochester, NY 14623, USA 43.0844955 -77.6749311
# Trichy-Tanjore Road, Thirumalaisamudram, Thanjavur, Tamil Nadu 613401, India 10.7285131 79.0184111
# University Embankment, 7/9, Sankt-Peterburg, Russia, 199034 59.941894 30.2989199
# Bolshaya Morskaya Ulitsa, 67, Sankt-Peterburg, Russia, 190000 59.929491 30.2966081
# Politekhnicheskaya Ulitsa, 29, Sankt-Peterburg, Russia, 195251 60.00744979999999 30.3729617
# 1600 Holloway Ave, San Francisco, CA 94132, USA 37.7241492 -122.4799405
# 1 Washington Sq, San Jose, CA 95192, USA 37.3351874 -121.8810715
# China, Shanghai Shi, Minhang Qu, 东川路 邮政编码: 200240 31.0252201 121.4337784
# Tehran, خیابان آزادی، تهران بزرگ،، Iran 35.7036361 51.35156199999999
# Sartenejas, Caracas, Miranda, Venezuela 10.408363 -66.8755735
# 8888 University Dr, Burnaby, BC V5A 1S6, Canada 49.2780937 -122.9198833
# Ulitsa Przhevalskogo, 4, Smolensk, Smolenskaya oblast, Russia, 214000 54.7845032 32.0452469
# 1801 E Cotati Ave, Rohnert Park, CA 94928, USA 38.3395854 -122.6743811
# 3140 S Federal St, Chicago, IL 60616, USA 41.8367719 -87.6291633
# Strada Ion Ghica 13, București 030045, Romania 44.4332166 26.1009718
# 450 Serra Mall, Stanford, CA 94305, USA 37.4274745 -122.169719
# Cidade Universitária Zeferino Vaz - Barão Geraldo, Campinas - SP, 13083-970, Brazil -22.8184393 -47.0647206
# 7060 NY-104, Oswego, NY 13126, USA 43.45139280000001 -76.5425285
# Stellenbosch Central, Stellenbosch, South Africa -33.9328078 18.864447
# 320 Washington St, North Easton, MA 02357, USA 42.0590153 -71.0806276
# Narva maantee 25, 10120 Tallinn, Estonia 59.4387321 24.7713836
# Ehitajate tee 5, 12616 Tallinn, Estonia 59.3959451 24.6710596
# Korkeakoulunkatu 7 Kampusareena, 33720 Tampere, Finland 61.4498286 23.8589986
# El-Gaish, Tanta Qism 2, Tanta, Gharbia Governorate, Egypt 30.7924391 30.9991409
# 1500 Houston St, Fort Worth, TX 76102, USA 32.7474661 -97.3278753
# Strada Memorandumului 28, Cluj-Napoca 400114, Romania 46.769299 23.585613
# Linkkikatu 15, 21100 Naantali, Finland 60.4706859 22.0694608
# Tel Aviv-Yafo, Israel 32.1133141 34.8043877
# Velachery Main Rd, Narayanapuram, Pallikaranai, Chennai, Tamil Nadu 600100, India 12.9452892 80.207843
# Raiņa bulvāris 19, Centra rajons, Rīga, LV-1586, Latvia 56.95080979999999 24.1163132
# Oxford Rd, Manchester M13 9PL, UK 53.4668498 -2.2338837
# Preller St, Muckleneuk, Pretoria, 0002, South Africa -25.7676588 28.1992637
# 300 N Broadway, Lexington, KY 40508, USA 38.0516801 -84.49334189999999
# 419 Boston Ave, Medford, MA 02155, USA 42.4074843 -71.1190232
# Berkeley, CA, USA 37.8718992 -122.2585399
# Los Angeles, CA 90095, USA 34.068921 -118.4451811
# 9500 Gilman Dr, La Jolla, CA 92093, USA 32.8800604 -117.2340135
# Champaign, IL, USA 40.1019523 -88.2271615
# 1049 University Dr, Duluth, MN 55812, USA 46.8173234 -92.0846134
# 7400 E Arapahoe Rd # 10, Centennial, CO 80112, USA 39.5944197 -104.9024568
# Viamonte 430, C1053 CABA, Argentina -34.5998875 -58.37306949999999
# Rambla del Poblenou, 156, 08018 Barcelona, Spain 41.4063164 2.1947066
# Los Angeles, CA 90007, USA 34.0223519 -118.285117
# Madison, WI, USA 43.076592 -89.4124875
# Caracas, Capital District, Venezuela 10.4883502 -66.8891696
# Av. Séneca, 2, 28040 Madrid, Spain 40.4375731 -3.7252231
# Bucaramanga, Santander, Colombia 7.1297913 -73.1136365
# República de Brasil 33 Centro, Centro Histórico de la Cdad. de México, Centro Historico, Cuauhtémoc, 06320 Ciudad de México, CDMX, Mexico 19.4379866 -99.1333401
# Avenida 1, Calle 9 Heredia 86, Heredia, 3000, Costa Rica 9.9986898 -84.11118979999999
# Cra 45, Bogotá, Colombia 4.6381938 -74.08404639999999
# Calle Colombia 154, La Paz, Bolivia -16.500656 -68.134299
# Viamonte 430, C1053 CABA, Argentina -34.5998875 -58.37306949999999
# Av. Camilo José Cela, 50, 13071 Ciudad Real, Cdad. Real, Spain 38.99404390000001 -3.9204979
# Cra. 1 #18a 12, Bogotá, Cundinamarca, Colombia 4.601476 -74.06639
# Via Alterna, Puerto La Cruz 6001, Anzoátegui, Venezuela 10.1732454 -64.6525884
# 11 Av, Guatemala 01012, Guatemala 14.587349 -90.55341399999999
# C/Plaza de Santa Cruz, 8, 47002 Valladolid, Spain 41.6569271 -4.7140547
# Chía, Cundinamarca, Colombia 4.8615787 -74.0325368
# 18 Avenida 11-95 Guatemala, Guatemala 01015, Guatemala 14.603762 -90.48924799999999
# Campus I - Lot. Cidade Universitaria, João Pessoa - PB, 58051-900, Brazil -7.1377579 -34.8458995
# R. Eng. Agronômico Andrei Cristian Ferreira, s/n - Trindade, Florianópolis - SC, 88040-900, Brazil -27.6000837 -48.5194214
# Av. Paulo Gama, 110 - Farroupilha, Porto Alegre - RS, 90040-060, Brazil -30.0336054 -51.2198408
# Av. Pedro Calmon, 550 - Cidade Universitária da Universidade Federal do Rio de Janeiro, Rio de Janeiro - RJ, 21941-901, Brazil -22.8617077 -43.2234035
# Av. Rovisco Pais 1, 1049-001 Lisboa, Portugal 38.7368192 -9.138705
# Butanta, São Paulo - State of São Paulo, Brazil -23.5613991 -46.7307891
# R. da Universidade, 4710-057 Braga, Portugal 41.5607319 -8.3962368
# 200 records written to where.js
# Open where.html to view the data in a browser

# %%
zap = "hello there bob"
print(zap[4])
# Out:
# o

# %%
x = 12
if x < 5:
print("smaller")
else:
    print("bigger")
print("all done")
# Out:
#   File "<ipython-input-9-adfc3d2d2a4c>", line 3
#     print("smaller")
#         ^
# IndentationError: expected an indented block

# %%
def fred():
   print("Zap")

def jane():
   print("ABC")

jane()
fred()
jane()
# Out:
# ABC
# Zap
# ABC

# %%
if x < 2 :
    print("Below 2")
elif x < 0 :
    print("Negative")
else :
    print("Something else")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-084e21df9c56> in <module>
# ----> 1 if x < 2 :
#       2     print("Below 2")
#       3 elif x < 0 :
#       4     print("Negative")
#       5 else :
#
# NameError: name 'x' is not defined

# %%
stuff = ['joseph', 'sally', 'walter', 'tim']
print(stuff[2])
# Out:
# walter

# %%
def hello():
    print("Hello")
    print("There")

x = 10
x = x + 1

# %%
x = -1
for value in [3, 41, 12, 9, 74, 15] :
    print('loop',value)
    if value > x :
        x = value
        print('checking',x)
print(x)
# Out:
# loop 3
# checking 3
# loop 41
# checking 41
# loop 12
# loop 9
# loop 74
# checking 74
# loop 15
# 74

# %%
total = 0
for abc in range(5):
    total = total + abc
print(total)
# Out:
# 10

# %%
a = "123"
b = 456
c = a + b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-833eb22d1061> in <module>
#       1 a = "123"
#       2 b = 456
# ----> 3 c = a + b
#       4 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
line1
try:
     line2
     line3
     line4
except:
     line5
line6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-32f612273a57> in <module>
# ----> 1 line1
#       2 try:
#       3      line2
#       4      line3
#       5      line4
#
# NameError: name 'line1' is not defined

# %%
abc = "With three words"
stuff = abc.split()
print(stuff)
# Out:
# ['With', 'three', 'words']

# %%
abc = "With three words"
stuff = abc.split()
print(len(stuff))
# Out:
# 3

# %%
x=100
if x < 2 :
    print("Below 2")
elif x < 0 :
    print("Negative")
else :
    print("Something else")
# Out:
# Something else

# %%
Honor Case

# %%
import sqlite3
import urllib.error
import ssl
from urllib.parse import urljoin
from urllib.parse import urlparse
from urllib.request import urlopen
from bs4 import BeautifulSoup

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

conn = sqlite3.connect('spider.sqlite')
cur = conn.cursor()

cur.execute('''CREATE TABLE IF NOT EXISTS Pages
    (id INTEGER PRIMARY KEY, url TEXT UNIQUE, html TEXT,
     error INTEGER, old_rank REAL, new_rank REAL)''')

cur.execute('''CREATE TABLE IF NOT EXISTS Links
    (from_id INTEGER, to_id INTEGER)''')

cur.execute('''CREATE TABLE IF NOT EXISTS Webs (url TEXT UNIQUE)''')

# Check to see if we are already in progress...
cur.execute('SELECT id,url FROM Pages WHERE html is NULL and error is NULL ORDER BY RANDOM() LIMIT 1')
row = cur.fetchone()
if row is not None:
    print("Restarting existing crawl.  Remove spider.sqlite to start a fresh crawl.")
else :
    starturl = input('Enter web url or enter: ')
    if ( len(starturl) < 1 ) : starturl = 'http://www.dr-chuck.com/'
    if ( starturl.endswith('/') ) : starturl = starturl[:-1]
    web = starturl
    if ( starturl.endswith('.htm') or starturl.endswith('.html') ) :
        pos = starturl.rfind('/')
        web = starturl[:pos]

    if ( len(web) > 1 ) :
        cur.execute('INSERT OR IGNORE INTO Webs (url) VALUES ( ? )', ( web, ) )
        cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( starturl, ) )
        conn.commit()

# Get the current webs
cur.execute('''SELECT url FROM Webs''')
webs = list()
for row in cur:
    webs.append(str(row[0]))

print(webs)

many = 0
while True:
    if ( many < 1 ) :
        sval = input('How many pages:')
        if ( len(sval) < 1 ) : break
        many = int(sval)
    many = many - 1

    cur.execute('SELECT id,url FROM Pages WHERE html is NULL and error is NULL ORDER BY RANDOM() LIMIT 1')
    try:
        row = cur.fetchone()
        # print row
        fromid = row[0]
        url = row[1]
    except:
        print('No unretrieved HTML pages found')
        many = 0
        break

    print(fromid, url, end=' ')

    # If we are retrieving this page, there should be no links from it
    cur.execute('DELETE from Links WHERE from_id=?', (fromid, ) )
    try:
        document = urlopen(url, context=ctx)

        html = document.read()
        if document.getcode() != 200 :
            print("Error on page: ",document.getcode())
            cur.execute('UPDATE Pages SET error=? WHERE url=?', (document.getcode(), url) )

        if 'text/html' != document.info().get_content_type() :
            print("Ignore non text/html page")
            cur.execute('DELETE FROM Pages WHERE url=?', ( url, ) )
            conn.commit()
            continue

        print('('+str(len(html))+')', end=' ')

        soup = BeautifulSoup(html, "html.parser")
    except KeyboardInterrupt:
        print('')
        print('Program interrupted by user...')
        break
    except:
        print("Unable to retrieve or parse page")
        cur.execute('UPDATE Pages SET error=-1 WHERE url=?', (url, ) )
        conn.commit()
        continue

    cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( url, ) )
    cur.execute('UPDATE Pages SET html=? WHERE url=?', (memoryview(html), url ) )
    conn.commit()

    # Retrieve all of the anchor tags
    tags = soup('a')
    count = 0
    for tag in tags:
        href = tag.get('href', None)
        if ( href is None ) : continue
        # Resolve relative references like href="/contact"
        up = urlparse(href)
        if ( len(up.scheme) < 1 ) :
            href = urljoin(url, href)
        ipos = href.find('#')
        if ( ipos > 1 ) : href = href[:ipos]
        if ( href.endswith('.png') or href.endswith('.jpg') or href.endswith('.gif') ) : continue
        if ( href.endswith('/') ) : href = href[:-1]
        # print href
        if ( len(href) < 1 ) : continue

		# Check if the URL is in any of the webs
        found = False
        for web in webs:
            if ( href.startswith(web) ) :
                found = True
                break
        if not found : continue

        cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( href, ) )
        count = count + 1
        conn.commit()

        cur.execute('SELECT id FROM Pages WHERE url=? LIMIT 1', ( href, ))
        try:
            row = cur.fetchone()
            toid = row[0]
        except:
            print('Could not retrieve id')
            continue
        # print fromid, toid
        cur.execute('INSERT OR IGNORE INTO Links (from_id, to_id) VALUES ( ?, ? )', ( fromid, toid ) )


    print(count)

cur.close()
# Out:
# Restarting existing crawl.  Remove spider.sqlite to start a fresh crawl.
# ['http://www.dr-chuck.com', 'http://python-data.dr-chuck.net']
# How many pages:25
# 1959 http://python-data.dr-chuck.net/known_by_Salvador.html (12108) 100
# 1375 http://python-data.dr-chuck.net/known_by_Stanley.html (12053) 100
# 644 http://python-data.dr-chuck.net/known_by_Mhari.html (12024) 100
# 1254 http://python-data.dr-chuck.net/known_by_Debbie.html (12122) 100
# 4343 http://python-data.dr-chuck.net/known_by_Jeemie.html (12030) 100
# 3228 http://python-data.dr-chuck.net/known_by_Bodhan.html (12098) 100
# 2840 http://python-data.dr-chuck.net/known_by_Keryn.html (12035) 100
# 4005 http://python-data.dr-chuck.net/known_by_Rebbecah.html (12116)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1f7ea4d7d974> in <module>
#     142             continue
#     143         # print fromid, toid
# --> 144         cur.execute('INSERT OR IGNORE INTO Links (from_id, to_id) VALUES ( ?, ? )', ( fromid, toid ) )
#     145
#     146
#
# KeyboardInterrupt:

# %%
import sqlite3

conn = sqlite3.connect('spider.sqlite')
cur = conn.cursor()

cur.execute('''SELECT COUNT(from_id) AS inbound, old_rank, new_rank, id, url 
     FROM Pages JOIN Links ON Pages.id = Links.to_id
     WHERE html IS NOT NULL
     GROUP BY id ORDER BY inbound DESC''')

count = 0
for row in cur :
    if count < 50 : print(row)
    count = count + 1
print(count, 'rows.')
cur.close()
# Out:
# (6, None, 1.0, 1, 'http://www.dr-chuck.com')
# (6, None, 1.0, 346, 'http://python-data.dr-chuck.net/known_by_Erina.html')
# (5, None, 1.0, 207, 'http://python-data.dr-chuck.net/known_by_Adrien.html')
# (5, None, 1.0, 290, 'http://python-data.dr-chuck.net/known_by_Caela.html')
# (5, None, 1.0, 672, 'http://python-data.dr-chuck.net/known_by_Clyde.html')
# (5, None, 1.0, 985, 'http://python-data.dr-chuck.net/known_by_Yoji.html')
# (5, None, 1.0, 1136, 'http://python-data.dr-chuck.net/known_by_Stella.html')
# (5, None, 1.0, 1881, 'http://python-data.dr-chuck.net/known_by_Sheriff.html')
# (4, None, 1.0, 2, 'http://www.dr-chuck.com/dr-chuck/resume/index.htm')
# (4, None, 1.0, 47, 'http://python-data.dr-chuck.net/known_by_Jaydon.html')
# (4, None, 1.0, 133, 'http://python-data.dr-chuck.net/known_by_Khalan.html')
# (4, None, 1.0, 218, 'http://python-data.dr-chuck.net/known_by_Maneet.html')
# (4, None, 1.0, 576, 'http://python-data.dr-chuck.net/known_by_Talon.html')
# (4, None, 1.0, 1091, 'http://python-data.dr-chuck.net/known_by_Tamara.html')
# (4, None, 1.0, 1144, 'http://python-data.dr-chuck.net/known_by_Evie.html')
# (4, None, 1.0, 1231, 'http://python-data.dr-chuck.net/known_by_Milie.html')
# (4, None, 1.0, 1348, 'http://python-data.dr-chuck.net/known_by_Morran.html')
# (4, None, 1.0, 1460, 'http://python-data.dr-chuck.net/known_by_Ann.html')
# (4, None, 1.0, 1604, 'http://python-data.dr-chuck.net/known_by_Risa.html')
# (4, None, 1.0, 2333, 'http://python-data.dr-chuck.net/known_by_Pacey.html')
# (4, None, 1.0, 2630, 'http://python-data.dr-chuck.net/known_by_Daisy.html')
# (4, None, 1.0, 3026, 'http://python-data.dr-chuck.net/known_by_Xiao.html')
# (4, None, 1.0, 3278, 'http://python-data.dr-chuck.net/known_by_Inez.html')
# (3, None, 1.0, 52, 'http://python-data.dr-chuck.net/known_by_Loudon.html')
# (3, None, 1.0, 187, 'http://python-data.dr-chuck.net/known_by_Evey.html')
# (3, None, 1.0, 188, 'http://python-data.dr-chuck.net/known_by_Anureet.html')
# (3, None, 1.0, 360, 'http://python-data.dr-chuck.net/known_by_Aislinn.html')
# (3, None, 1.0, 395, 'http://python-data.dr-chuck.net/known_by_Lagan.html')
# (3, None, 1.0, 477, 'http://python-data.dr-chuck.net/known_by_Evalina.html')
# (3, None, 1.0, 936, 'http://python-data.dr-chuck.net/known_by_Irmak.html')
# (3, None, 1.0, 992, 'http://python-data.dr-chuck.net/known_by_Teigan.html')
# (3, None, 1.0, 1375, 'http://python-data.dr-chuck.net/known_by_Stanley.html')
# (3, None, 1.0, 1959, 'http://python-data.dr-chuck.net/known_by_Salvador.html')
# (3, None, 1.0, 2033, 'http://python-data.dr-chuck.net/known_by_Jordi.html')
# (3, None, 1.0, 2086, 'http://python-data.dr-chuck.net/known_by_Macaully.html')
# (3, None, 1.0, 2383, 'http://python-data.dr-chuck.net/known_by_Jardine.html')
# (3, None, 1.0, 2715, 'http://python-data.dr-chuck.net/known_by_Jorjia.html')
# (3, None, 1.0, 2843, 'http://python-data.dr-chuck.net/known_by_Janette.html')
# (3, None, 1.0, 3032, 'http://python-data.dr-chuck.net/known_by_Jorja.html')
# (3, None, 1.0, 3178, 'http://python-data.dr-chuck.net/known_by_Alyshia.html')
# (2, None, 1.0, 10, 'http://www.dr-chuck.com/dr-chuck/resume/bio.htm')
# (2, None, 1.0, 16, 'http://www.dr-chuck.com/dr-chuck/resume/speaking.htm')
# (2, None, 1.0, 18, 'http://www.dr-chuck.com/dr-chuck/resume')
# (2, None, 1.0, 36, 'http://python-data.dr-chuck.net/comments_42.html')
# (2, None, 1.0, 138, 'http://python-data.dr-chuck.net/known_by_Finnlay.html')
# (2, None, 1.0, 166, 'http://python-data.dr-chuck.net/known_by_Derryn.html')
# (2, None, 1.0, 211, 'http://python-data.dr-chuck.net/known_by_Safa.html')
# (2, None, 1.0, 286, 'http://python-data.dr-chuck.net/known_by_Eiley.html')
# (2, None, 1.0, 377, 'http://python-data.dr-chuck.net/known_by_Emilia.html')
# (2, None, 1.0, 381, 'http://python-data.dr-chuck.net/known_by_Aarman.html')
# 117 rows.

# %%
import sqlite3
import urllib.error
import ssl
from urllib.parse import urljoin
from urllib.parse import urlparse
from urllib.request import urlopen
from bs4 import BeautifulSoup

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

conn = sqlite3.connect('spider.sqlite')
cur = conn.cursor()

cur.execute('''CREATE TABLE IF NOT EXISTS Pages
    (id INTEGER PRIMARY KEY, url TEXT UNIQUE, html TEXT,
     error INTEGER, old_rank REAL, new_rank REAL)''')

cur.execute('''CREATE TABLE IF NOT EXISTS Links
    (from_id INTEGER, to_id INTEGER)''')

cur.execute('''CREATE TABLE IF NOT EXISTS Webs (url TEXT UNIQUE)''')

# Check to see if we are already in progress...
cur.execute('SELECT id,url FROM Pages WHERE html is NULL and error is NULL ORDER BY RANDOM() LIMIT 1')
row = cur.fetchone()
if row is not None:
    print("Restarting existing crawl.  Remove spider.sqlite to start a fresh crawl.")
else :
    starturl = input('Enter web url or enter: ')
    if ( len(starturl) < 1 ) : starturl = 'http://www.dr-chuck.com/'
    if ( starturl.endswith('/') ) : starturl = starturl[:-1]
    web = starturl
    if ( starturl.endswith('.htm') or starturl.endswith('.html') ) :
        pos = starturl.rfind('/')
        web = starturl[:pos]

    if ( len(web) > 1 ) :
        cur.execute('INSERT OR IGNORE INTO Webs (url) VALUES ( ? )', ( web, ) )
        cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( starturl, ) )
        conn.commit()

# Get the current webs
cur.execute('''SELECT url FROM Webs''')
webs = list()
for row in cur:
    webs.append(str(row[0]))

print(webs)

many = 0
while True:
    if ( many < 1 ) :
        sval = input('How many pages:')
        if ( len(sval) < 1 ) : break
        many = int(sval)
    many = many - 1

    cur.execute('SELECT id,url FROM Pages WHERE html is NULL and error is NULL ORDER BY RANDOM() LIMIT 1')
    try:
        row = cur.fetchone()
        # print row
        fromid = row[0]
        url = row[1]
    except:
        print('No unretrieved HTML pages found')
        many = 0
        break

    print(fromid, url, end=' ')

    # If we are retrieving this page, there should be no links from it
    cur.execute('DELETE from Links WHERE from_id=?', (fromid, ) )
    try:
        document = urlopen(url, context=ctx)

        html = document.read()
        if document.getcode() != 200 :
            print("Error on page: ",document.getcode())
            cur.execute('UPDATE Pages SET error=? WHERE url=?', (document.getcode(), url) )

        if 'text/html' != document.info().get_content_type() :
            print("Ignore non text/html page")
            cur.execute('DELETE FROM Pages WHERE url=?', ( url, ) )
            conn.commit()
            continue

        print('('+str(len(html))+')', end=' ')

        soup = BeautifulSoup(html, "html.parser")
    except KeyboardInterrupt:
        print('')
        print('Program interrupted by user...')
        break
    except:
        print("Unable to retrieve or parse page")
        cur.execute('UPDATE Pages SET error=-1 WHERE url=?', (url, ) )
        conn.commit()
        continue

    cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( url, ) )
    cur.execute('UPDATE Pages SET html=? WHERE url=?', (memoryview(html), url ) )
    conn.commit()

    # Retrieve all of the anchor tags
    tags = soup('a')
    count = 0
    for tag in tags:
        href = tag.get('href', None)
        if ( href is None ) : continue
        # Resolve relative references like href="/contact"
        up = urlparse(href)
        if ( len(up.scheme) < 1 ) :
            href = urljoin(url, href)
        ipos = href.find('#')
        if ( ipos > 1 ) : href = href[:ipos]
        if ( href.endswith('.png') or href.endswith('.jpg') or href.endswith('.gif') ) : continue
        if ( href.endswith('/') ) : href = href[:-1]
        # print href
        if ( len(href) < 1 ) : continue

		# Check if the URL is in any of the webs
        found = False
        for web in webs:
            if ( href.startswith(web) ) :
                found = True
                break
        if not found : continue

        cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( href, ) )
        count = count + 1
        conn.commit()

        cur.execute('SELECT id FROM Pages WHERE url=? LIMIT 1', ( href, ))
        try:
            row = cur.fetchone()
            toid = row[0]
        except:
            print('Could not retrieve id')
            continue
        # print fromid, toid
        cur.execute('INSERT OR IGNORE INTO Links (from_id, to_id) VALUES ( ?, ? )', ( fromid, toid ) )


    print(count)

cur.close()

# %%
import sqlite3

conn = sqlite3.connect('spider.sqlite')
cur = conn.cursor()

print("Creating JSON output on spider.js...")
howmany = int(input("How many nodes? "))

cur.execute('''SELECT COUNT(from_id) AS inbound, old_rank, new_rank, id, url 
    FROM Pages JOIN Links ON Pages.id = Links.to_id
    WHERE html IS NOT NULL AND ERROR IS NULL
    GROUP BY id ORDER BY id,inbound''')

fhand = open('spider.js','w')
nodes = list()
maxrank = None
minrank = None
for row in cur :
    nodes.append(row)
    rank = row[2]
    if maxrank is None or maxrank < rank: maxrank = rank
    if minrank is None or minrank > rank : minrank = rank
    if len(nodes) > howmany : break

if maxrank == minrank or maxrank is None or minrank is None:
    print("Error - please run sprank.py to compute page rank")
    quit()

fhand.write('spiderJson = {"nodes":[\n')
count = 0
map = dict()
ranks = dict()
for row in nodes :
    if count > 0 : fhand.write(',\n')
    # print row
    rank = row[2]
    rank = 19 * ( (rank - minrank) / (maxrank - minrank) ) 
    fhand.write('{'+'"weight":'+str(row[0])+',"rank":'+str(rank)+',')
    fhand.write(' "id":'+str(row[3])+', "url":"'+row[4]+'"}')
    map[row[3]] = count
    ranks[row[3]] = rank
    count = count + 1
fhand.write('],\n')

cur.execute('''SELECT DISTINCT from_id, to_id FROM Links''')
fhand.write('"links":[\n')

count = 0
for row in cur :
    # print row
    if row[0] not in map or row[1] not in map : continue
    if count > 0 : fhand.write(',\n')
    rank = ranks[row[0]]
    srank = 19 * ( (rank - minrank) / (maxrank - minrank) ) 
    fhand.write('{"source":'+str(map[row[0]])+',"target":'+str(map[row[1]])+',"value":3}')
    count = count + 1
fhand.write(']};')
fhand.close()
cur.close()

print("Open force.html in a browser to view the visualization")
# Out:
# Creating JSON output on spider.js...
# How many nodes? 25
# Error - please run sprank.py to compute page rank
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-8dfc98e8845b> in <module>
#      35     # print row
#      36     rank = row[2]
# ---> 37     rank = 19 * ( (rank - minrank) / (maxrank - minrank) )
#      38     fhand.write('{'+'"weight":'+str(row[0])+',"rank":'+str(rank)+',')
#      39     fhand.write(' "id":'+str(row[3])+', "url":"'+row[4]+'"}')
#
# ZeroDivisionError: float division by zero

# %%
#https://blog.csdn.net/weixin_41706353/article/details/79440760

# %% [markdown]
# # JSon

# %%
import json

data = '''
[
  { "id" : "001",
    "x" : "2",
    "name" : "Chuck"
  } ,
  { "id" : "009",
    "x" : "7",
    "name" : "Brent"
  }
]'''

info = json.loads(data)
print('User count:', len(info))

for item in info:
    print('Name', item['name'])
    print('Id', item['id'])
    print('Attribute', item['x'])
# Out:
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Brent
# Id 009
# Attribute 7

# %%
from urllib.parse import urljoin
from urllib.parse import urlparse
from urllib.request import urlopen
count = 0
url = input("Enter json URL: ")
#url = "http://py4e-data.dr-chuck.net/comments_271795.json"
#print "retrieving URL. Stand by."
uh = urlopen(url)
data= uh.read()

info = json.loads(data)
for item in info["comments"]:
    
    number = int(item["count"])
    count = count + number
print(count)
# Out:
# Enter json URL: http://py4e-data.dr-chuck.net/comments_271795.json
# 2659

# %%
connection = urlopen(url)
raw_data = connection.read()
parsed_data = json.loads(raw_data)
counts = []

comments = parsed_data["comments"]

for comment in comments:
    counts.append(comment['count'])

print ("Count: {0}".format(len(counts)))
print ("Sum: {0}".format(sum(counts)))
# Out:
# Count: 50
# Sum: 2659

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: South Federal University
# Retrieving http://py4e-data.dr-chuck.net/json?address=South+Federal+University&key=42
# Retrieved 2291 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "3140",
#                     "short_name": "3140",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "South Federal Street",
#                     "short_name": "S Federal St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Douglas",
#                     "short_name": "Douglas",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Chicago",
#                     "short_name": "Chicago",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Cook County",
#                     "short_name": "Cook County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Illinois",
#                     "short_name": "IL",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "60616",
#                     "short_name": "60616",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "3140 S Federal St, Chicago, IL 60616, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8367719,
#                     "lng": -87.6291633
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.8381208802915,
#                         "lng": -87.62781431970849
#                     },
#                     "southwest": {
#                         "lat": 41.8354229197085,
#                         "lng": -87.6305122802915
#                     }
#                 }
#             },
#             "place_id": "ChIJ9e_QQm0sDogRhUPatldEFxw",
#             "plus_code": {
#                 "compound_code": "R9PC+P8 Chicago, Illinois, United States",
#                 "global_code": "86HJR9PC+P8"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "university"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 41.8367719 lng -87.6291633
# 3140 S Federal St, Chicago, IL 60616, USA
# Enter location:

# %%
import urllib.error, urllib.request, urllib.parse
import json
target = 'http://py4e-data.dr-chuck.net/json?' 
local = input('Enter location: ')
url = target + urllib.parse.urlencode({'address': local, 'key' : 42})
print('Retriving', url)
data = urllib.request.urlopen(url).read()
print('Retrived', len(data), 'characters')
js = json.loads(data)
# print(json.dumps(js, indent = 4)) 
print('Place id', js['results'][0]['place_id'])
# Out:
# Enter location: UCSD
# Retriving http://py4e-data.dr-chuck.net/json?address=UCSD&key=42
# Retrived 2302 characters
# Place id ChIJT69MQcQG3IARpz6Rifyqtu8

# %%
import sqlite3
import time
import ssl
import urllib.request, urllib.parse, urllib.error
from urllib.parse import urljoin
from urllib.parse import urlparse
import re
from datetime import datetime, timedelta

# Not all systems have this so conditionally define parser
try:
    import dateutil.parser as parser
except:
    pass

def parsemaildate(md) :
    # See if we have dateutil
    try:
        pdate = parser.parse(tdate)
        test_at = pdate.isoformat()
        return test_at
    except:
        pass

    # Non-dateutil version - we try our best

    pieces = md.split()
    notz = " ".join(pieces[:4]).strip()

    # Try a bunch of format variations - strptime() is *lame*
    dnotz = None
    for form in [ '%d %b %Y %H:%M:%S', '%d %b %Y %H:%M:%S',
        '%d %b %Y %H:%M', '%d %b %Y %H:%M', '%d %b %y %H:%M:%S',
        '%d %b %y %H:%M:%S', '%d %b %y %H:%M', '%d %b %y %H:%M' ] :
        try:
            dnotz = datetime.strptime(notz, form)
            break
        except:
            continue

    if dnotz is None :
        # print 'Bad Date:',md
        return None

    iso = dnotz.isoformat()

    tz = "+0000"
    try:
        tz = pieces[4]
        ival = int(tz) # Only want numeric timezone values
        if tz == '-0000' : tz = '+0000'
        tzh = tz[:3]
        tzm = tz[3:]
        tz = tzh+":"+tzm
    except:
        pass

    return iso+tz

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

conn = sqlite3.connect('content.sqlite')
cur = conn.cursor()

baseurl = "http://mbox.dr-chuck.net/sakai.devel/"

cur.execute('''CREATE TABLE IF NOT EXISTS Messages
    (id INTEGER UNIQUE, email TEXT, sent_at TEXT,
     subject TEXT, headers TEXT, body TEXT)''')

# Pick up where we left off
start = None
cur.execute('SELECT max(id) FROM Messages' )
try:
    row = cur.fetchone()
    if row is None :
        start = 0
    else:
        start = row[0]
except:
    start = 0

if start is None : start = 0

many = 0
count = 0
fail = 0
while True:
    if ( many < 1 ) :
        conn.commit()
        sval = input('How many messages:')
        if ( len(sval) < 1 ) : break
        many = int(sval)

    start = start + 1
    cur.execute('SELECT id FROM Messages WHERE id=?', (start,) )
    try:
        row = cur.fetchone()
        if row is not None : continue
    except:
        row = None

    many = many - 1
    url = baseurl + str(start) + '/' + str(start + 1)

    text = "None"
    try:
        # Open with a timeout of 30 seconds
        document = urllib.request.urlopen(url, None, 30, context=ctx)
        text = document.read().decode()
        if document.getcode() != 200 :
            print("Error code=",document.getcode(), url)
            break
    except KeyboardInterrupt:
        print('')
        print('Program interrupted by user...')
        break
    except Exception as e:
        print("Unable to retrieve or parse page",url)
        print("Error",e)
        fail = fail + 1
        if fail > 5 : break
        continue

    print(url,len(text))
    count = count + 1

    if not text.startswith("From "):
        print(text)
        print("Did not find From ")
        fail = fail + 1
        if fail > 5 : break
        continue

    pos = text.find("\n\n")
    if pos > 0 :
        hdr = text[:pos]
        body = text[pos+2:]
    else:
        print(text)
        print("Could not find break between headers and body")
        fail = fail + 1
        if fail > 5 : break
        continue

    email = None
    x = re.findall('\nFrom: .* <(\S+@\S+)>\n', hdr)
    if len(x) == 1 :
        email = x[0];
        email = email.strip().lower()
        email = email.replace("<","")
    else:
        x = re.findall('\nFrom: (\S+@\S+)\n', hdr)
        if len(x) == 1 :
            email = x[0];
            email = email.strip().lower()
            email = email.replace("<","")

    date = None
    y = re.findall('\Date: .*, (.*)\n', hdr)
    if len(y) == 1 :
        tdate = y[0]
        tdate = tdate[:26]
        try:
            sent_at = parsemaildate(tdate)
        except:
            print(text)
            print("Parse fail",tdate)
            fail = fail + 1
            if fail > 5 : break
            continue

    subject = None
    z = re.findall('\Subject: (.*)\n', hdr)
    if len(z) == 1 : subject = z[0].strip().lower();

    # Reset the fail counter
    fail = 0
    print("   ",email,sent_at,subject)
    cur.execute('''INSERT OR IGNORE INTO Messages (id, email, sent_at, subject, headers, body)
        VALUES ( ?, ?, ?, ?, ?, ? )''', ( start, email, sent_at, subject, hdr, body))
    if count % 50 == 0 : conn.commit()
    if count % 100 == 0 : time.sleep(1)

conn.commit()
cur.close()
# Out:
# How many messages:100
# http://mbox.dr-chuck.net/sakai.devel/1/2 2662
#     ggolden@umich.edu 2005-12-08T23:34:30-06:00 call for participation: developers documentation
# http://mbox.dr-chuck.net/sakai.devel/2/3 2434
#     csev@umich.edu 2005-12-09T00:58:01-05:00 report from the austin conference:  sakai developers break into song
# http://mbox.dr-chuck.net/sakai.devel/3/4 3055
#     kevin.carpenter@rsmart.com 2005-12-09T09:01:49-07:00 cas and sakai 1.5
# http://mbox.dr-chuck.net/sakai.devel/4/5 11721
#     michael.feldstein@suny.edu 2005-12-09T09:43:12-05:00 re: lms/vle rants/comments
# http://mbox.dr-chuck.net/sakai.devel/5/6 9443
#     john@caret.cam.ac.uk 2005-12-09T13:32:29+00:00 re: lms/vle rants/comments
# http://mbox.dr-chuck.net/sakai.devel/6/7 3586
#     s-githens@northwestern.edu 2005-12-09T13:32:31-06:00 re: sakaiportallogin and presense
# http://mbox.dr-chuck.net/sakai.devel/7/8 10600
#     john@caret.cam.ac.uk 2005-12-09T13:42:24+00:00 re: lms/vle rants/comments
# http://mbox.dr-chuck.net/sakai.devel/8/9 4892
#     s-githens@northwestern.edu 2005-12-09T15:23:09-06:00 re: sakaiportallogin and presense
# http://mbox.dr-chuck.net/sakai.devel/9/10 3206
#     ys2n@virginia.edu 2005-12-09T17:54:17+00:00 sakaiportallogin and presense
# http://mbox.dr-chuck.net/sakai.devel/10/11 4993
#     ys2n@virginia.edu 2005-12-09T21:16:39+00:00 re: sakaiportallogin and presense
# http://mbox.dr-chuck.net/sakai.devel/11/12 3298
#     slt@columbia.edu 2005-12-09T23:16:40-05:00 re: cas and sakai 1.5
# http://mbox.dr-chuck.net/sakai.devel/12/13 3096
#     dgcotton@ucdavis.edu 2005-12-10T20:55:54-08:00 memory error with 2.1
# http://mbox.dr-chuck.net/sakai.devel/13/14 4307
#     vyu2@yahoo.com 2005-12-10T23:34:43-08:00 re: memory error with 2.1
# http://mbox.dr-chuck.net/sakai.devel/14/15 4935
#     winstonw.tw@gmail.com 2005-12-11T03:07:29+08:00 re: sakai ldap authentication
# http://mbox.dr-chuck.net/sakai.devel/15/16 4374
#     ajpoland@iupui.edu 2005-12-11T12:08:15-05:00 re: memory error with 2.1
# http://mbox.dr-chuck.net/sakai.devel/16/17 2475
#     caseyd1@stanford.edu 2005-12-12T07:02:36-08:00 re: sakai 2.1 provider examples
# http://mbox.dr-chuck.net/sakai.devel/17/18 3931
#     aaronz@vt.edu 2005-12-12T08:55:09-05:00 sakai 2.1 provider examples
# http://mbox.dr-chuck.net/sakai.devel/18/19 3828
#     j.higham@hull.ac.uk 2005-12-12T09:49:16+00:00 re: sakai 2.1 - lone zero block error
# http://mbox.dr-chuck.net/sakai.devel/19/20 2839
#     aaronz@vt.edu 2005-12-12T10:13:38-05:00 re: sakai 2.1 provider examples
# http://mbox.dr-chuck.net/sakai.devel/20/21 8505
#     jeffrey.beeman@asu.edu 2005-12-12T11:14:55-07:00 re: sakai logo
# http://mbox.dr-chuck.net/sakai.devel/21/22 2625
#     csev@umich.edu 2005-12-12T11:33:29-05:00 sepp library discussion group renamed - now with open membership
# http://mbox.dr-chuck.net/sakai.devel/22/23 2960
#     pgoldweic@northwestern.edu 2005-12-12T13:16:12-06:00 problems accessing the collab site with internet explorer...
# http://mbox.dr-chuck.net/sakai.devel/23/24 4715
#     pgoldweic@northwestern.edu 2005-12-12T14:20:41-06:00 re: problems accessing the collab site with internet
# http://mbox.dr-chuck.net/sakai.devel/24/25 2705
#     andrew@caret.cam.ac.uk 2005-12-12T14:23:12+00:00 file picker for non-legacy tools
# http://mbox.dr-chuck.net/sakai.devel/25/26 4378
#     john.ellis@rsmart.com 2005-12-12T14:24:48-07:00 re: file picker for non-legacy tools
# http://mbox.dr-chuck.net/sakai.devel/26/27 3403
#     aaronz@vt.edu 2005-12-12T14:42:01-05:00 sakai 2.01 vt provider code
# http://mbox.dr-chuck.net/sakai.devel/27/28 3932
#     aaronz@vt.edu 2005-12-12T14:54:49-05:00 re: problems accessing the collab site with internet explorer...
# http://mbox.dr-chuck.net/sakai.devel/28/29 5170
#     jxf@immagic.com 2005-12-12T16:41:04-05:00 re: worksite taxonomy
# http://mbox.dr-chuck.net/sakai.devel/29/30 3845
#     ray@media.berkeley.edu 2005-12-12T17:03:51-08:00 re: sakai 2.1 samigo
# http://mbox.dr-chuck.net/sakai.devel/30/31 5262
#     dave.ross@gmail.com 2005-12-12T17:49:13-05:00 re: memory error with 2.1
# http://mbox.dr-chuck.net/sakai.devel/31/32 5043
#     clayf@bu.edu 2005-12-12T18:31:23-05:00 re: memory error with 2.1
# http://mbox.dr-chuck.net/sakai.devel/32/33 2910
#     ggolden@umich.edu 2005-12-12T20:02:00-05:00 sakai 2.1 conversion - an update
# http://mbox.dr-chuck.net/sakai.devel/33/34 3512
#     ys2n@virginia.edu 2005-12-12T21:15:22+00:00 worksite taxonomy
# http://mbox.dr-chuck.net/sakai.devel/34/35 5362
#     lfernandez@weber.edu 2005-12-13T01:08:01-07:00 re: memory error with 2.1
# http://mbox.dr-chuck.net/sakai.devel/35/36 2270
#     lfernandez@weber.edu 2005-12-13T01:29:49-07:00 audio recordings of austin presentations
# http://mbox.dr-chuck.net/sakai.devel/36/37 6958
#     ys2n@virginia.edu 2005-12-13T02:46:51+00:00 re: worksite taxonomy
# http://mbox.dr-chuck.net/sakai.devel/37/38 8425
#     jleasia@umich.edu 2005-12-13T08:02:47-05:00 re: worksite taxonomy
# http://mbox.dr-chuck.net/sakai.devel/38/39 3014
#     csev@umich.edu 2005-12-13T08:12:08-05:00 re: audio recordings of austin presentations
# http://mbox.dr-chuck.net/sakai.devel/39/40 9459
#     gsilver@umich.edu 2005-12-13T08:58:10-05:00 re: worksite taxonomy
# http://mbox.dr-chuck.net/sakai.devel/40/41 4796
#     jrm@jhu.edu 2005-12-13T09:32:39-05:00 sakai 2.1 db error?
# http://mbox.dr-chuck.net/sakai.devel/41/42 2692
#     slt@columbia.edu 2005-12-13T10:15:28-05:00 re: sakai 2.1 conversion - an update
# http://mbox.dr-chuck.net/sakai.devel/42/43 2640
#     ray@media.berkeley.edu 2005-12-13T12:07:02-08:00 big news in jsf land
# http://mbox.dr-chuck.net/sakai.devel/43/44 3016
#     antranig@caret.cam.ac.uk 2005-12-13T14:06:13+00:00 "direct urls"
# http://mbox.dr-chuck.net/sakai.devel/44/45 2988
#     jmpease@syr.edu 2005-12-13T14:45:24-05:00 entity model
# http://mbox.dr-chuck.net/sakai.devel/45/46 9703
#     gwang3@unlnotes.unl.edu 2005-12-13T14:50:25-06:00 error to run sakai 2.1
# http://mbox.dr-chuck.net/sakai.devel/46/47 9703
#     gwang3@unlnotes.unl.edu 2005-12-13T14:50:25-06:00 error to run sakai 2.1
# http://mbox.dr-chuck.net/sakai.devel/47/48 15775
#     bkirschn@umich.edu 2005-12-13T14:55:24-05:00 utf-8 problem on sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/48/49 3230
#     vrajgopalan@ucmerced.edu 2005-12-13T15:02:42-08:00 regarding the section manager and other section related api's
# http://mbox.dr-chuck.net/sakai.devel/49/50 3214
#     vrajgopalan@ucmerced.edu 2005-12-13T15:23:15-08:00 regarding the section manager and other section related api's
# http://mbox.dr-chuck.net/sakai.devel/50/51 2848
#     wchang@dri.edu 2005-12-13T15:23:26-08:00 password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/51/52 5509
#     jholtzman@berkeley.edu 2005-12-13T15:35:43-08:00 re: regarding the section manager and other section related api's
# http://mbox.dr-chuck.net/sakai.devel/52/53 19248
#     bkirschn@umich.edu 2005-12-13T16:17:28-05:00 re: utf-8 problem on sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/53/54 8985
#     ys2n@virginia.edu 2005-12-13T16:33:19-05:00 re: worksite taxonomy
# http://mbox.dr-chuck.net/sakai.devel/54/55 2767
#     listuser@chillco.com 2005-12-13T16:51:48-08:00 sakai configuration document mia?
# http://mbox.dr-chuck.net/sakai.devel/55/56 9758
#     gwang3@unlnotes.unl.edu 2005-12-13T16:54:52-06:00 error to run sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/56/57 10930
#     clayf@bu.edu 2005-12-13T16:59:46-05:00 re: error to run sakai 2.1
# http://mbox.dr-chuck.net/sakai.devel/57/58 2357
#     tannirumurthy@fhda.edu 2005-12-13T17:40:18-08:00 converting sakai 2.0 tables to sakai 2.1
# http://mbox.dr-chuck.net/sakai.devel/58/59 7263
#     s-githens@northwestern.edu 2005-12-13T17:56:09-06:00 re: regarding the section manager and other section related api's
# http://mbox.dr-chuck.net/sakai.devel/59/60 3277
#     tannirumurthy@fhda.edu 2005-12-13T18:30:52-08:00 re: converting sakai 2.0 tables to sakai 2.1
# http://mbox.dr-chuck.net/sakai.devel/60/61 3389
#     jleasia@umich.edu 2005-12-13T20:16:27-05:00 re: sakai configuration document mia?
# http://mbox.dr-chuck.net/sakai.devel/61/62 18418
#     fribeiro@ufp.pt 2005-12-13T20:42:26+00:00 re: utf-8 problem on sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/62/63 3280
#     ggolden@umich.edu 2005-12-13T21:18:41-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/63/64 3480
#     iros@student.umass.edu 2005-12-13T21:19:04-05:00 presence tool and virtual paths...
# http://mbox.dr-chuck.net/sakai.devel/64/65 21272
#     masayang.mobile@gmail.com 2005-12-13T22:47:23-08:00 re: utf-8 problem on sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/65/66 3399
#     lfernandez@weber.edu 2005-12-13T23:22:34-07:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/66/67 4536
#     lfernandez@weber.edu 2005-12-13T23:43:16-07:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/67/68 5449
#     cheryl.wogahn@yale.edu 2005-12-14T08:46:29-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/68/69 7980
#     lfernandez@weber.edu 2005-12-14T08:49:28-07:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/69/70 3684
#     clayf@bu.edu 2005-12-14T08:49:31-05:00 re: sakai 2.1 webdav
# http://mbox.dr-chuck.net/sakai.devel/70/71 3905
#     ggolden@umich.edu 2005-12-14T09:31:52-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/71/72 2914
#     jmpease@syr.edu 2005-12-14T09:32:45-05:00 re: myfaces 1.1.1 with sakai 2.1, anyone?
# http://mbox.dr-chuck.net/sakai.devel/72/73 21301
#     bkirschn@umich.edu 2005-12-14T09:39:11-05:00 re: utf-8 problem on sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/73/74 7030
#     ys2n@virginia.edu 2005-12-14T09:39:19-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/74/75 6445
#     dave.ross@gmail.com 2005-12-14T09:39:52-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/75/76 2329
#     k.cheng@ust.hk 2005-12-14T09:45:09+08:00 myfaces 1.1.1 with sakai 2.1, anyone?
# http://mbox.dr-chuck.net/sakai.devel/76/77 24907
#     jwilliamson@oid.ucla.edu 2005-12-14T09:58:13-08:00 re: utf-8 problem on sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/77/78 7204
#     zqian@umich.edu 2005-12-14T09:58:32-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/78/79 6886
#     cheryl.wogahn@yale.edu 2005-12-14T10:01:23-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/79/80 7854
#     cheryl.wogahn@yale.edu 2005-12-14T10:05:20-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/80/81 8324
#     dave.ross@gmail.com 2005-12-14T10:08:14-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/81/82 4293
#     listuser@chillco.com 2005-12-14T10:11:27-08:00 re: sakai configuration document mia?
# http://mbox.dr-chuck.net/sakai.devel/82/83 2533
#     csev@umich.edu 2005-12-14T10:29:42-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/83/84 5226
#     dgcotton@ucdavis.edu 2005-12-14T10:44:57-08:00 re: memory error with 2.1
# http://mbox.dr-chuck.net/sakai.devel/84/85 8625
#     zqian@umich.edu 2005-12-14T10:48:19-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/85/86 3320
#     slt@columbia.edu 2005-12-14T10:53:16-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/86/87 4275
#     raad@caret.cam.ac.uk 2005-12-14T11:00:30+00:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/87/88 9905
#     j.higham@hull.ac.uk 2005-12-14T11:06:02+00:00 re: sakai 2.1 webdav
# http://mbox.dr-chuck.net/sakai.devel/88/89 3793
#     csev@umich.edu 2005-12-14T11:24:00-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/89/90 9180
#     ggolden@umich.edu 2005-12-14T11:28:55-05:00 re: password forgotten feature
# http://mbox.dr-chuck.net/sakai.devel/90/91 3532
#     gissurj@ruc.dk 2005-12-14T12:30:28+01:00 re: audio recordings of austin presentations
# http://mbox.dr-chuck.net/sakai.devel/91/92 4091
#     mak05307@yahoo.com 2005-12-14T12:40:54-08:00 resources tool
# http://mbox.dr-chuck.net/sakai.devel/92/93 4840
#     sinouvivian@foothill.edu 2005-12-14T13:00:41-08:00 re: resources tool
# http://mbox.dr-chuck.net/sakai.devel/93/94 5565
#     clayf@bu.edu 2005-12-14T13:14:39-05:00 re: sakai 2.1 webdav
# http://mbox.dr-chuck.net/sakai.devel/94/95 2462
#     aaronz@vt.edu 2005-12-14T13:42:39-05:00 creating a site on collab
# http://mbox.dr-chuck.net/sakai.devel/95/96 10673
#     gwang3@unlnotes.unl.edu 2005-12-14T13:47:16-06:00 re: error to run sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/96/97 11995
#     gwang3@unlnotes.unl.edu 2005-12-14T15:18:45-06:00 re: error to run sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/97/98 13544
#     gwang3@unlnotes.unl.edu 2005-12-14T16:01:59-06:00 re: error to run sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/98/99 11488
#     zqian@umich.edu 2005-12-14T16:02:13-05:00 re: error to run sakai 2.1 with mysql
# http://mbox.dr-chuck.net/sakai.devel/99/100 3297
#     csev@umich.edu 2005-12-14T16:22:23-05:00 sakai 2.2 schedule - high level
# http://mbox.dr-chuck.net/sakai.devel/100/101 13022
#     zqian@umich.edu 2005-12-14T16:32:19-05:00 re: error to run sakai 2.1 with mysql
# How many messages:

# %%
import sqlite3
import time
import re
import zlib
from datetime import datetime, timedelta

# Not all systems have this
try:
    import dateutil.parser as parser
except:
    pass

dnsmapping = dict()
mapping = dict()

def fixsender(sender,allsenders=None) :
    global dnsmapping
    global mapping
    if sender is None : return None
    sender = sender.strip().lower()
    sender = sender.replace('<','').replace('>','')

    # Check if we have a hacked gmane.org from address
    if allsenders is not None and sender.endswith('gmane.org') :
        pieces = sender.split('-')
        realsender = None
        for s in allsenders:
            if s.startswith(pieces[0]) :
                realsender = sender
                sender = s
                # print(realsender, sender)
                break
        if realsender is None :
            for s in mapping:
                if s.startswith(pieces[0]) :
                    realsender = sender
                    sender = mapping[s]
                    # print(realsender, sender)
                    break
        if realsender is None : sender = pieces[0]

    mpieces = sender.split("@")
    if len(mpieces) != 2 : return sender
    dns = mpieces[1]
    x = dns
    pieces = dns.split(".")
    if dns.endswith(".edu") or dns.endswith(".com") or dns.endswith(".org") or dns.endswith(".net") :
        dns = ".".join(pieces[-2:])
    else:
        dns = ".".join(pieces[-3:])
    # if dns != x : print(x,dns)
    # if dns != dnsmapping.get(dns,dns) : print(dns,dnsmapping.get(dns,dns))
    dns = dnsmapping.get(dns,dns)
    return mpieces[0] + '@' + dns

def parsemaildate(md) :
    # See if we have dateutil
    try:
        pdate = parser.parse(md)
        test_at = pdate.isoformat()
        return test_at
    except:
        pass

    # Non-dateutil version - we try our best

    pieces = md.split()
    notz = " ".join(pieces[:4]).strip()

    # Try a bunch of format variations - strptime() is *lame*
    dnotz = None
    for form in [ '%d %b %Y %H:%M:%S', '%d %b %Y %H:%M:%S',
        '%d %b %Y %H:%M', '%d %b %Y %H:%M', '%d %b %y %H:%M:%S',
        '%d %b %y %H:%M:%S', '%d %b %y %H:%M', '%d %b %y %H:%M' ] :
        try:
            dnotz = datetime.strptime(notz, form)
            break
        except:
            continue

    if dnotz is None :
        # print('Bad Date:',md)
        return None

    iso = dnotz.isoformat()

    tz = "+0000"
    try:
        tz = pieces[4]
        ival = int(tz) # Only want numeric timezone values
        if tz == '-0000' : tz = '+0000'
        tzh = tz[:3]
        tzm = tz[3:]
        tz = tzh+":"+tzm
    except:
        pass

    return iso+tz

# Parse out the info...
def parseheader(hdr, allsenders=None):
    if hdr is None or len(hdr) < 1 : return None
    sender = None
    x = re.findall('\nFrom: .* <(\S+@\S+)>\n', hdr)
    if len(x) >= 1 :
        sender = x[0]
    else:
        x = re.findall('\nFrom: (\S+@\S+)\n', hdr)
        if len(x) >= 1 :
            sender = x[0]

    # normalize the domain name of Email addresses
    sender = fixsender(sender, allsenders)

    date = None
    y = re.findall('\nDate: .*, (.*)\n', hdr)
    sent_at = None
    if len(y) >= 1 :
        tdate = y[0]
        tdate = tdate[:26]
        try:
            sent_at = parsemaildate(tdate)
        except Exception as e:
            # print('Date ignored ',tdate, e)
            return None

    subject = None
    z = re.findall('\nSubject: (.*)\n', hdr)
    if len(z) >= 1 : subject = z[0].strip().lower()

    guid = None
    z = re.findall('\nMessage-ID: (.*)\n', hdr)
    if len(z) >= 1 : guid = z[0].strip().lower()

    if sender is None or sent_at is None or subject is None or guid is None :
        return None
    return (guid, sender, subject, sent_at)

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('''DROP TABLE IF EXISTS Messages ''')
cur.execute('''DROP TABLE IF EXISTS Senders ''')
cur.execute('''DROP TABLE IF EXISTS Subjects ''')
cur.execute('''DROP TABLE IF EXISTS Replies ''')

cur.execute('''CREATE TABLE IF NOT EXISTS Messages
    (id INTEGER PRIMARY KEY, guid TEXT UNIQUE, sent_at INTEGER,
     sender_id INTEGER, subject_id INTEGER,
     headers BLOB, body BLOB)''')
cur.execute('''CREATE TABLE IF NOT EXISTS Senders
    (id INTEGER PRIMARY KEY, sender TEXT UNIQUE)''')
cur.execute('''CREATE TABLE IF NOT EXISTS Subjects
    (id INTEGER PRIMARY KEY, subject TEXT UNIQUE)''')
cur.execute('''CREATE TABLE IF NOT EXISTS Replies
    (from_id INTEGER, to_id INTEGER)''')

conn_1 = sqlite3.connect('mapping.sqlite')
cur_1 = conn_1.cursor()

cur_1.execute('''SELECT old,new FROM DNSMapping''')
for message_row in cur_1 :
    dnsmapping[message_row[0].strip().lower()] = message_row[1].strip().lower()

mapping = dict()
cur_1.execute('''SELECT old,new FROM Mapping''')
for message_row in cur_1 :
    old = fixsender(message_row[0])
    new = fixsender(message_row[1])
    mapping[old] = fixsender(new)

# Done with mapping.sqlite
conn_1.close()

# Open the main content (Read only)
conn_1 = sqlite3.connect('file:content.sqlite?mode=ro', uri=True)
cur_1 = conn_1.cursor()

allsenders = list()
cur_1.execute('''SELECT email FROM Messages''')
for message_row in cur_1 :
    sender = fixsender(message_row[0])
    if sender is None : continue
    if 'gmane.org' in sender : continue
    if sender in allsenders: continue
    allsenders.append(sender)

print("Loaded allsenders",len(allsenders),"and mapping",len(mapping),"dns mapping",len(dnsmapping))

cur_1.execute('''SELECT headers, body, sent_at
    FROM Messages ORDER BY sent_at''')

senders = dict()
subjects = dict()
guids = dict()

count = 0

for message_row in cur_1 :
    hdr = message_row[0]
    parsed = parseheader(hdr, allsenders)
    if parsed is None: continue
    (guid, sender, subject, sent_at) = parsed

    # Apply the sender mapping
    sender = mapping.get(sender,sender)

    count = count + 1
    if count % 250 == 1 : print(count,sent_at, sender)
    # print(guid, sender, subject, sent_at)

    if 'gmane.org' in sender:
        print("Error in sender ===", sender)

    sender_id = senders.get(sender,None)
    subject_id = subjects.get(subject,None)
    guid_id = guids.get(guid,None)

    if sender_id is None :
        cur.execute('INSERT OR IGNORE INTO Senders (sender) VALUES ( ? )', ( sender, ) )
        conn.commit()
        cur.execute('SELECT id FROM Senders WHERE sender=? LIMIT 1', ( sender, ))
        try:
            row = cur.fetchone()
            sender_id = row[0]
            senders[sender] = sender_id
        except:
            print('Could not retrieve sender id',sender)
            break
    if subject_id is None :
        cur.execute('INSERT OR IGNORE INTO Subjects (subject) VALUES ( ? )', ( subject, ) )
        conn.commit()
        cur.execute('SELECT id FROM Subjects WHERE subject=? LIMIT 1', ( subject, ))
        try:
            row = cur.fetchone()
            subject_id = row[0]
            subjects[subject] = subject_id
        except:
            print('Could not retrieve subject id',subject)
            break
    # print(sender_id, subject_id)
    cur.execute('INSERT OR IGNORE INTO Messages (guid,sender_id,subject_id,sent_at,headers,body) VALUES ( ?,?,?,datetime(?),?,? )',
            ( guid, sender_id, subject_id, sent_at,
            zlib.compress(message_row[0].encode()), zlib.compress(message_row[1].encode())) )
    conn.commit()
    cur.execute('SELECT id FROM Messages WHERE guid=? LIMIT 1', ( guid, ))
    try:
        row = cur.fetchone()
        message_id = row[0]
        guids[guid] = message_id
    except:
        print('Could not retrieve guid id',guid)
        break

cur.close()
cur_1.close()
# Out:
# Loaded allsenders 47 and mapping 29 dns mapping 1
# 1 2005-12-08T23:34:30-06:00 ggolden22@mac.com

# %%
import sqlite3
import time
import zlib

howmany = int(input("How many to dump? "))

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('SELECT id, sender FROM Senders')
senders = dict()
for message_row in cur :
    senders[message_row[0]] = message_row[1]

cur.execute('SELECT id, subject FROM Subjects')
subjects = dict()
for message_row in cur :
    subjects[message_row[0]] = message_row[1]

# cur.execute('SELECT id, guid,sender_id,subject_id,headers,body FROM Messages')
cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
messages = dict()
for message_row in cur :
    messages[message_row[0]] = (message_row[1],message_row[2],message_row[3],message_row[4])

print("Loaded messages=",len(messages),"subjects=",len(subjects),"senders=",len(senders))

sendcounts = dict()
sendorgs = dict()
for (message_id, message) in list(messages.items()):
    sender = message[1]
    sendcounts[sender] = sendcounts.get(sender,0) + 1
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    sendorgs[dns] = sendorgs.get(dns,0) + 1

print('')
print('Top',howmany,'Email list participants')

x = sorted(sendcounts, key=sendcounts.get, reverse=True)
for k in x[:howmany]:
    print(senders[k], sendcounts[k])
    if sendcounts[k] < 10 : break

print('')
print('Top',howmany,'Email list organizations')

x = sorted(sendorgs, key=sendorgs.get, reverse=True)
for k in x[:howmany]:
    print(k, sendorgs[k])
    if sendorgs[k] < 10 : break
# Out:
# How many to dump? 2
# Loaded messages= 100 subjects= 54 senders= 47
#
# Top 2 Email list participants
# csev@umich.edu 6
#
# Top 2 Email list organizations
# umich.edu 16
# virginia.edu 6

# %% [markdown]
# # Visulaization

# %%
import sqlite3
import time
import zlib

howmany = int(input("How many to dump? "))

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('SELECT id, sender FROM Senders')
senders = dict()
for message_row in cur :
    senders[message_row[0]] = message_row[1]

cur.execute('SELECT id, subject FROM Subjects')
subjects = dict()
for message_row in cur :
    subjects[message_row[0]] = message_row[1]

# cur.execute('SELECT id, guid,sender_id,subject_id,headers,body FROM Messages')
cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
messages = dict()
for message_row in cur :
    messages[message_row[0]] = (message_row[1],message_row[2],message_row[3],message_row[4])

print("Loaded messages=",len(messages),"subjects=",len(subjects),"senders=",len(senders))

sendcounts = dict()
sendorgs = dict()
for (message_id, message) in list(messages.items()):
    sender = message[1]
    sendcounts[sender] = sendcounts.get(sender,0) + 1
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    sendorgs[dns] = sendorgs.get(dns,0) + 1

print('')
print('Top',howmany,'Email list participants')

x = sorted(sendcounts, key=sendcounts.get, reverse=True)
for k in x[:howmany]:
    print(senders[k], sendcounts[k])
    if sendcounts[k] < 10 : break

print('')
print('Top',howmany,'Email list organizations')

x = sorted(sendorgs, key=sendorgs.get, reverse=True)
for k in x[:howmany]:
    print(k, sendorgs[k])
    if sendorgs[k] < 10 : break
# Out:
# How many to dump? 5
# Loaded messages= 100 subjects= 54 senders= 47
#
# Top 5 Email list participants
# csev@umich.edu 6
#
# Top 5 Email list organizations
# umich.edu 16
# virginia.edu 6

# %%
import sqlite3
import time
import zlib
import string

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('SELECT id, subject FROM Subjects')
subjects = dict()
for message_row in cur :
    subjects[message_row[0]] = message_row[1]

# cur.execute('SELECT id, guid,sender_id,subject_id,headers,body FROM Messages')
cur.execute('SELECT subject_id FROM Messages')
counts = dict()
for message_row in cur :
    text = subjects[message_row[0]]
    text = text.translate(str.maketrans('','',string.punctuation))
    text = text.translate(str.maketrans('','','1234567890'))
    text = text.strip()
    text = text.lower()
    words = text.split()
    for word in words:
        if len(word) < 4 : continue
        counts[word] = counts.get(word,0) + 1

x = sorted(counts, key=counts.get, reverse=True)
highest = None
lowest = None
for k in x[:100]:
    if highest is None or highest < counts[k] :
        highest = counts[k]
    if lowest is None or lowest > counts[k] :
        lowest = counts[k]
print('Range of counts:',highest,lowest)

# Spread the font sizes across 20-100 based on the count
bigsize = 80
smallsize = 20

fhand = open('gword.js','w')
fhand.write("gword = [")
first = True
for k in x[:100]:
    if not first : fhand.write( ",\n")
    first = False
    size = counts[k]
    size = (size - lowest) / float(highest - lowest)
    size = int((size * bigsize) + smallsize)
    fhand.write("{text: '"+k+"', size: "+str(size)+"}")
fhand.write( "\n];\n")
fhand.close()

print("Output written to gword.js")
print("Open gword.htm in a browser to see the vizualization")
# Out:
# Range of counts: 42 1
# Output written to gword.js
# Open gword.htm in a browser to see the vizualization

# %%
import sqlite3
import time
import zlib

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('SELECT id, sender FROM Senders')
senders = dict()
for message_row in cur :
    senders[message_row[0]] = message_row[1]

cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
messages = dict()
for message_row in cur :
    messages[message_row[0]] = (message_row[1],message_row[2],message_row[3],message_row[4])

print("Loaded messages=",len(messages),"senders=",len(senders))

sendorgs = dict()
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    sendorgs[dns] = sendorgs.get(dns,0) + 1

# pick the top schools
orgs = sorted(sendorgs, key=sendorgs.get, reverse=True)
orgs = orgs[:10]
print("Top 10 Organizations")
print(orgs)

counts = dict()
months = list()
# cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    if dns not in orgs : continue
    month = message[3][:7]
    if month not in months : months.append(month)
    key = (month, dns)
    counts[key] = counts.get(key,0) + 1

months.sort()
# print counts
# print months

fhand = open('gline.js','w')
fhand.write("gline = [ ['Month'")
for org in orgs:
    fhand.write(",'"+org+"'")
fhand.write("]")

for month in months:
    fhand.write(",\n['"+month+"'")
    for org in orgs:
        key = (month, org)
        val = counts.get(key,0)
        fhand.write(","+str(val))
    fhand.write("]");

fhand.write("\n];\n")
fhand.close()

print("Output written to gline.js")
print("Open gline.htm to visualize the data")
# Out:
# Loaded messages= 100 senders= 47
# Top 10 Organizations
# ['umich.edu', 'virginia.edu', 'unl.edu', 'mac.com', 'cam.ac.uk', 'gmail.com', 'unicon.net', 'weber.edu', 'gatech.edu', 'mtu.edu']
# Output written to gline.js
# Open gline.htm to visualize the data

# %%
import sqlite3
import time
import zlib

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('SELECT id, sender FROM Senders')
senders = dict()
for message_row in cur :
    senders[message_row[0]] = message_row[1]

cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
messages = dict()
for message_row in cur :
    messages[message_row[0]] = (message_row[1],message_row[2],message_row[3],message_row[4])

print("Loaded messages=",len(messages),"senders=",len(senders))

sendorgs = dict()
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    sendorgs[dns] = sendorgs.get(dns,0) + 1

# pick the top schools
orgs = sorted(sendorgs, key=sendorgs.get, reverse=True)
orgs = orgs[:10]
print("Top 10 Organizations")
print(orgs)

counts = dict()
months = list()
# cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    if dns not in orgs : continue
    month = message[3][:7]
    if month not in months : months.append(month)
    key = (month, dns)
    counts[key] = counts.get(key,0) + 1

months.sort()
# print counts
# print months

fhand = open('gline.js','w')
fhand.write("gline = [ ['Month'")
for org in orgs:
    fhand.write(",'"+org+"'")
fhand.write("]")

for month in months:
    fhand.write(",\n['"+month+"'")
    for org in orgs:
        key = (month, org)
        val = counts.get(key,0)
        fhand.write(","+str(val))
    fhand.write("]");

fhand.write("\n];\n")
fhand.close()

print("Output written to gline.js")
print("Open gline.htm to visualize the data")
# Out:
# Loaded messages= 100 senders= 47
# Top 10 Organizations
# ['umich.edu', 'virginia.edu', 'unl.edu', 'mac.com', 'cam.ac.uk', 'gmail.com', 'unicon.net', 'weber.edu', 'gatech.edu', 'mtu.edu']
# Output written to gline.js
# Open gline.htm to visualize the data

# %%
import sqlite3
import time
import zlib

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('SELECT id, sender FROM Senders')
senders = dict()
for message_row in cur :
    senders[message_row[0]] = message_row[1]

cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
messages = dict()
for message_row in cur :
    messages[message_row[0]] = (message_row[1],message_row[2],message_row[3],message_row[4])

print("Loaded messages=",len(messages),"senders=",len(senders))

sendorgs = dict()
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    sendorgs[dns] = sendorgs.get(dns,0) + 1

# pick the top schools
orgs = sorted(sendorgs, key=sendorgs.get, reverse=True)
orgs = orgs[:10]
print("Top 10 Organizations")
print(orgs)

counts = dict()
months = list()
# cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    if dns not in orgs : continue
    month = message[3][:4]
    if month not in months : months.append(month)
    key = (month, dns)
    counts[key] = counts.get(key,0) + 1

months.sort()
# print counts
# print months

fhand = open('gline.js','w')
fhand.write("gline = [ ['Month'")
for org in orgs:
    fhand.write(",'"+org+"'")
fhand.write("]")

for month in months:
    fhand.write(",\n['"+month+"'")
    for org in orgs:
        key = (month, org)
        val = counts.get(key,0)
        fhand.write(","+str(val))
    fhand.write("]");

fhand.write("\n];\n")
fhand.close()

print("Output written to gline.js")
print("Open gline.htm to visualize the data")
# Out:
# Loaded messages= 100 senders= 47
# Top 10 Organizations
# ['umich.edu', 'virginia.edu', 'unl.edu', 'mac.com', 'cam.ac.uk', 'gmail.com', 'unicon.net', 'weber.edu', 'gatech.edu', 'mtu.edu']
# Output written to gline.js
# Open gline.htm to visualize the data

# %%
By Year

# %%
import sqlite3
import time
import urllib.request, urllib.parse, urllib.error
import zlib

conn = sqlite3.connect('index.sqlite')
cur = conn.cursor()

cur.execute('SELECT id, sender FROM Senders')
senders = dict()
for message_row in cur :
    senders[message_row[0]] = message_row[1]

cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
messages = dict()
for message_row in cur :
    messages[message_row[0]] = (message_row[1],message_row[2],message_row[3],message_row[4])

print("Loaded messages=",len(messages),"senders=",len(senders))

sendorgs = dict()
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    sendorgs[dns] = sendorgs.get(dns,0) + 1

# pick the top schools
orgs = sorted(sendorgs, key=sendorgs.get, reverse=True)
orgs = orgs[:10]
print("Top 10 Oranizations")
print(orgs)
# orgs = ['total'] + orgs

counts = dict()
months = list()
# cur.execute('SELECT id, guid,sender_id,subject_id,sent_at FROM Messages')
for (message_id, message) in list(messages.items()):
    sender = message[1]
    pieces = senders[sender].split("@")
    if len(pieces) != 2 : continue
    dns = pieces[1]
    if dns not in orgs : continue
    month = message[3][:4]
    if month not in months : months.append(month)
    key = (month, dns)
    counts[key] = counts.get(key,0) + 1
    tkey = (month, 'total')
    counts[tkey] = counts.get(tkey,0) + 1
    
months.sort()
# print counts
# print months

fhand = open('gline.js','w')
fhand.write("gline = [ ['Year'")
for org in orgs:
    fhand.write(",'"+org+"'")
fhand.write("]")

for month in months[1:-1]:
    fhand.write(",\n['"+month+"'")
    for org in orgs:
        key = (month, org)
        val = counts.get(key,0)
        fhand.write(","+str(val))
    fhand.write("]");

fhand.write("\n];\n")
fhand.close()

print("Output written to gline.js")
print("Open gline.htm to visualize the data")
# Out:
# Loaded messages= 100 senders= 47
# Top 10 Oranizations
# ['umich.edu', 'virginia.edu', 'unl.edu', 'mac.com', 'cam.ac.uk', 'gmail.com', 'unicon.net', 'weber.edu', 'gatech.edu', 'mtu.edu']
# Output written to gline.js
# Open gline.htm to visualize the data
